# %% [markdown]
# #Task 9.1 - Study of Data : S1 Sample

# %%
from pandas.io import gbq
from matplotlib import pyplot as plt
import pandas as pd

# %%
df_social_behaviors = gbq.read_gbq('select * from Students.social_behaviors',project_id='ipads2020-assignment9')
df_conv_frequency = gbq.read_gbq('select * from Students.convo_frequency',project_id='ipads2020-assignment9')
df_conv_duration = gbq.read_gbq('select * from Students.convo_duration',project_id='ipads2020-assignment9')

# %% [markdown]
# ##Information of the Data

# %% [markdown]
# ###Social Behaviour Table

# %%
df_social_behaviors.isna().any()
# Out:
# userid               False
# convo_num_day_avg    False
# convo_dur_day_avg    False
# female               False
# age                   True
# dtype: bool

# %%
df_social_behaviors.convo_num_day_avg.fillna(df_social_behaviors.convo_num_day_avg.mean())
# Out:
# 0     47.473684
# 1     24.654545
# 2     31.390244
# 3     35.049180
# 4     24.742424
# 5     29.814815
# 6     26.578947
# 7     28.461538
# 8     34.830508
# 9     41.180328
# 10    33.224490
# 11    15.549020
# 12    33.730769
# 13    32.574468
# 14    34.358491
# 15    31.300000
# 16    25.071429
# 17    60.129032
# 18    37.435484
# 19    24.075000
# 20    32.685185
# 21    33.400000
# 22    10.500000
# 23    41.408163
# 24    24.200000
# 25    33.107692
# 26     9.738095
# 27    31.984848
# 28    23.292683
# 29    27.260000
# 30    27.232558
# 31    22.590164
# 32    22.527778
# 33    22.882353
# 34    22.964286
# 35    32.964912
# 36    28.246154
# 37    22.553846
# 38    28.907407
# 39    19.171875
# 40    28.230769
# 41    23.150000
# 42    25.966102
# 43    30.322581
# 44    25.400000
# 45    29.982759
# 46    30.657143
# 47    21.000000
# Name: convo_num_day_avg, dtype: float64

# %%
df_social_behaviors
# Out:
#    userid  convo_num_day_avg convo_dur_day_avg  female   age
# 0     u04          47.473684       421.8704678       0   NaN
# 1     u05          24.654545       236.9439394       0   NaN
# 2     u07          31.390244       279.4654472       0   NaN
# 3     u09          35.049180       428.3740437       0   NaN
# 4     u12          24.742424        237.170202       0   NaN
# 5     u14          29.814815       405.3697531       0   NaN
# 6     u22          26.578947       247.0127193       0   NaN
# 7     u25          28.461538       393.5814103       0   NaN
# 8     u27          34.830508       242.1115819       0   NaN
# 9     u31          41.180328       309.5259563       0   NaN
# 10    u32          33.224490       463.8380952       0   NaN
# 11    u33          15.549020       256.5075163       0   NaN
# 12    u34          33.730769       309.2205128       0   NaN
# 13    u43          32.574468       324.0265957       0   NaN
# 14    u46          34.358491       418.1314465       0   NaN
# 15    u49          31.300000       265.9916667       0   NaN
# 16    u56          25.071429       214.5282738       0   NaN
# 17    u59          60.129032       367.8352151       0   NaN
# 18    u08          37.435484       332.6607527       0  20.0
# 19    u41          24.075000       249.6654167       0  20.0
# 20    u13          32.685185       221.9216049       0  21.0
# 21    u24          33.400000       377.1944444       0  21.0
# 22    u52          10.500000       82.87270115       0  21.0
# 23    u01          41.408163       505.8227891       0  22.0
# 24    u44          24.200000       162.0457576       0  22.0
# 25    u57          33.107692       344.4158974       0  22.0
# 26    u03           9.738095       58.74126984       0  23.0
# 27    u10          31.984848       211.4752525       0  23.0
# 28    u20          23.292683       156.8971545       0  23.0
# 29    u58          27.260000       373.3873333       0  23.0
# 30    u54          27.232558                NA       0  23.0
# 31    u35          22.590164       191.9653005       0  24.0
# 32    u47          22.527778       142.4421296       0  24.0
# 33    u50          22.882353       133.1921569       0  25.0
# 34    u23          22.964286       175.3901786       0  26.0
# 35    u36          32.964912       230.8912281       0  28.0
# 36    u51          28.246154       204.8025641       0  29.0
# 37    u02          22.553846       314.3830769       1   NaN
# 38    u16          28.907407       261.3901235       1   NaN
# 39    u17          19.171875       170.6947917       1   NaN
# 40    u15          28.230769       306.8589744       1  20.0
# 41    u18          23.150000          247.2975       1  20.0
# 42    u19          25.966102       224.1966102       1  20.0
# 43    u30          30.322581        445.766129       1  21.0
# 44    u42          25.400000       234.2029167       1  23.0
# 45    u53          29.982759       257.5341954       1  23.0
# 46    u45          30.657143       306.3414286       1  24.0
# 47    u39          21.000000              85.8       1  25.0

# %%
df_social_behaviors['convo_num_day_avg'].plot(kind = 'hist', bins = 40)

# %% [markdown]
# Most of the students have a call frequency if 23 Times a Day

# %%
df_social_behaviors.replace('NA',373.38, inplace = True)

# %%
df_social_behaviors
# Out:
#    userid  convo_num_day_avg convo_dur_day_avg  female   age
# 0     u04          47.473684       421.8704678       0   NaN
# 1     u05          24.654545       236.9439394       0   NaN
# 2     u07          31.390244       279.4654472       0   NaN
# 3     u09          35.049180       428.3740437       0   NaN
# 4     u12          24.742424        237.170202       0   NaN
# 5     u14          29.814815       405.3697531       0   NaN
# 6     u22          26.578947       247.0127193       0   NaN
# 7     u25          28.461538       393.5814103       0   NaN
# 8     u27          34.830508       242.1115819       0   NaN
# 9     u31          41.180328       309.5259563       0   NaN
# 10    u32          33.224490       463.8380952       0   NaN
# 11    u33          15.549020       256.5075163       0   NaN
# 12    u34          33.730769       309.2205128       0   NaN
# 13    u43          32.574468       324.0265957       0   NaN
# 14    u46          34.358491       418.1314465       0   NaN
# 15    u49          31.300000       265.9916667       0   NaN
# 16    u56          25.071429       214.5282738       0   NaN
# 17    u59          60.129032       367.8352151       0   NaN
# 18    u08          37.435484       332.6607527       0  20.0
# 19    u41          24.075000       249.6654167       0  20.0
# 20    u13          32.685185       221.9216049       0  21.0
# 21    u24          33.400000       377.1944444       0  21.0
# 22    u52          10.500000       82.87270115       0  21.0
# 23    u01          41.408163       505.8227891       0  22.0
# 24    u44          24.200000       162.0457576       0  22.0
# 25    u57          33.107692       344.4158974       0  22.0
# 26    u03           9.738095       58.74126984       0  23.0
# 27    u10          31.984848       211.4752525       0  23.0
# 28    u20          23.292683       156.8971545       0  23.0
# 29    u58          27.260000       373.3873333       0  23.0
# 30    u54          27.232558            373.38       0  23.0
# 31    u35          22.590164       191.9653005       0  24.0
# 32    u47          22.527778       142.4421296       0  24.0
# 33    u50          22.882353       133.1921569       0  25.0
# 34    u23          22.964286       175.3901786       0  26.0
# 35    u36          32.964912       230.8912281       0  28.0
# 36    u51          28.246154       204.8025641       0  29.0
# 37    u02          22.553846       314.3830769       1   NaN
# 38    u16          28.907407       261.3901235       1   NaN
# 39    u17          19.171875       170.6947917       1   NaN
# 40    u15          28.230769       306.8589744       1  20.0
# 41    u18          23.150000          247.2975       1  20.0
# 42    u19          25.966102       224.1966102       1  20.0
# 43    u30          30.322581        445.766129       1  21.0
# 44    u42          25.400000       234.2029167       1  23.0
# 45    u53          29.982759       257.5341954       1  23.0
# 46    u45          30.657143       306.3414286       1  24.0
# 47    u39          21.000000              85.8       1  25.0

# %%
df_social_behaviors.convo_dur_day_avg = df_social_behaviors.convo_dur_day_avg.astype(float)

# %%
df_social_behaviors['convo_dur_day_avg'].plot(kind = 'hist', bins = 30, color = 'red')

# %% [markdown]
# Most of the Students talk on an average duration of 220-230

# %%
df_social_behaviors.groupby(by = 'female').mean()
# Out:
#         convo_num_day_avg  convo_dur_day_avg        age
# female
# 0               29.692142         279.747805  23.157895
# 1               25.940226         259.496886  22.000000

# %% [markdown]
# Male Students are Elder and have more frequency and duration of talking.

# %% [markdown]
# ###Frequency Table

# %%
df_conv_frequency.columns
# Out:
# Index(['int64_field_0', 'string_field_1', 'string_field_2', 'string_field_3'], dtype='object')

# %%
df_conv_frequency.isna().any()
# Out:
# int64_field_0      True
# string_field_1    False
# string_field_2    False
# string_field_3    False
# dtype: bool

# %%
df_conv_frequency.columns = ['id','userid','date','sums_24hours']

# %%
df_conv_frequency.sums_24hours.replace('NA',29, inplace = True)
df_conv_frequency.dtypes
# Out:
# id              float64
# userid           object
# date             object
# sums_24hours     object
# dtype: object

# %%
df_conv_frequency = df_conv_frequency[:-1]
df_conv_frequency.sums_24hours = df_conv_frequency.sums_24hours.astype(float)

# %%
df_frequency_count = df_conv_frequency.groupby('userid').sum()
df_frequency_count.sort_values('sums_24hours', ascending=False)
# Out:
#               id  sums_24hours
# userid
# u59     106128.0        3844.0
# u04     103224.0        2967.0
# u31     104610.0        2657.0
# u01     103026.0        2522.0
# u08     103422.0        2437.0
# u09     103488.0        2283.0
# u27     104478.0        2258.0
# u46     105402.0        2198.0
# u57     105996.0        2181.0
# u36     104940.0        2140.0
# u32     104676.0        2121.0
# u13     103686.0        2113.0
# u10     103554.0        2111.0
# u43     105204.0        2082.0
# u24     104346.0        2046.0
# u34     104808.0        2037.0
# u49     105534.0        2029.0
# u07     103356.0        2012.0
# u30     104544.0        1996.0
# u45     105336.0        1972.0
# u53     105798.0        1971.0
# u14     103752.0        1958.0
# u16     103884.0        1909.0
# u25     104412.0        1900.0
# u15     103818.0        1894.0
# u51     105666.0        1865.0
# u54     105864.0        1838.0
# u58     106062.0        1827.0
# u22     104214.0        1822.0
# u39     105006.0        1778.0
# u42     105138.0        1770.0
# u19     104082.0        1735.0
# u41     105072.0        1717.0
# u50     105600.0        1706.0
# u56     105930.0        1694.0
# u47     105468.0        1681.0
# u20     104148.0        1680.0
# u18     104016.0        1680.0
# u05     103290.0        1675.0
# u44     105270.0        1650.0
# u12     103620.0        1633.0
# u23     104280.0        1576.0
# u35     104874.0        1523.0
# u02     103092.0        1495.0
# u17     103950.0        1285.0
# u33     104742.0        1228.0
# u03     103158.0        1105.0
# u52     105732.0         841.0

# %% [markdown]
# U59 has made calls the most times and U52 has made the least calls

# %% [markdown]
# ###Duration Data

# %%
df_conv_duration.columns
df_conv_duration.columns = ['id','userid','date','sum_24hours']

# %%
df_conv_duration = df_conv_duration[0:-1]

# %%
df_conv_duration.tail()
# Out:
#           id userid       date  sum_24hours
# 3163  3168.0    u59  X20130531  402.3666667
# 3164   768.0    u59  X20130411           NA
# 3165  2208.0    u59  X20130511           NA
# 3166  2352.0    u59  X20130514           NA
# 3167  2784.0    u59  X20130523           NA

# %%
df_conv_duration.replace('NA',275,inplace=True)

# %%
df_conv_duration.tail()
# Out:
#           id userid       date  sum_24hours
# 3163  3168.0    u59  X20130531  402.3666667
# 3164   768.0    u59  X20130411          275
# 3165  2208.0    u59  X20130511          275
# 3166  2352.0    u59  X20130514          275
# 3167  2784.0    u59  X20130523          275

# %%
df_conv_duration.dtypes
# Out:
# id             float64
# userid          object
# date            object
# sum_24hours     object
# dtype: object

# %%
df_conv_duration.sum_24hours = df_conv_duration.sum_24hours.astype(float)

# %%
df_dur_count = df_conv_duration.groupby('userid').sum()
print(df_dur_count)
df_dur_count.sort_values('sum_24hours', ascending=False)
# Out:
#               id   sum_24hours
# userid
# u01     103026.0  29460.316667
# u02     103092.0  20709.900000
# u03     103158.0   9067.133333
# u04     103224.0  26521.616667
# u05     103290.0  16056.916667
# u07     103356.0  18333.083333
# u08     103422.0  21724.966667
# u09     103488.0  27505.816667
# u10     103554.0  13957.366667
# u12     103620.0  15653.233334
# u13     103686.0  15283.766666
# u14     103752.0  25189.966667
# u15     103818.0  18978.333333
# u16     103884.0  17415.066666
# u17     103950.0  11474.466667
# u18     104016.0  17041.900000
# u19     104082.0  15152.600000
# u20     104148.0  13307.783333
# u22     104214.0  17086.483333
# u23     104280.0  12571.850000
# u24     104346.0  21215.833333
# u25     104412.0  21233.116667
# u27     104478.0  16209.583334
# u30     104544.0  28737.500000
# u31     104610.0  20256.083333
# u32     104676.0  27403.066666
# u33     104742.0  17206.883333
# u34     104808.0  19039.733333
# u35     104874.0  13084.883333
# u36     104940.0  15635.800000
# u39     105006.0  14933.600000
# u41     105072.0  17136.616667
# u42     105138.0  16518.116667
# u43     105204.0  20454.250000
# u44     105270.0  11937.516667
# u45     105336.0  19246.950000
# u46     105402.0  25735.966667
# u47     105468.0  13377.916667
# u49     105534.0  17699.583333
# u50     105600.0  13328.533333
# u51     105666.0  13587.166667
# u52     105732.0   7006.616667
# u53     105798.0  17136.983333
# u54     105864.0  18342.866667
# u56     105930.0  14763.583334
# u57     105996.0  22662.033333
# u58     106062.0  23069.366667
# u59     106128.0  23905.783334
#               id   sum_24hours
# userid
# u01     103026.0  29460.316667
# u30     104544.0  28737.500000
# u09     103488.0  27505.816667
# u32     104676.0  27403.066666
# u04     103224.0  26521.616667
# u46     105402.0  25735.966667
# u14     103752.0  25189.966667
# u59     106128.0  23905.783334
# u58     106062.0  23069.366667
# u57     105996.0  22662.033333
# u08     103422.0  21724.966667
# u25     104412.0  21233.116667
# u24     104346.0  21215.833333
# u02     103092.0  20709.900000
# u43     105204.0  20454.250000
# u31     104610.0  20256.083333
# u45     105336.0  19246.950000
# u34     104808.0  19039.733333
# u15     103818.0  18978.333333
# u54     105864.0  18342.866667
# u07     103356.0  18333.083333
# u49     105534.0  17699.583333
# u16     103884.0  17415.066666
# u33     104742.0  17206.883333
# u53     105798.0  17136.983333
# u41     105072.0  17136.616667
# u22     104214.0  17086.483333
# u18     104016.0  17041.900000
# u42     105138.0  16518.116667
# u27     104478.0  16209.583334
# u05     103290.0  16056.916667
# u12     103620.0  15653.233334
# u36     104940.0  15635.800000
# u13     103686.0  15283.766666
# u19     104082.0  15152.600000
# u39     105006.0  14933.600000
# u56     105930.0  14763.583334
# u10     103554.0  13957.366667
# u51     105666.0  13587.166667
# u47     105468.0  13377.916667
# u50     105600.0  13328.533333
# u20     104148.0  13307.783333
# u35     104874.0  13084.883333
# u23     104280.0  12571.850000
# u44     105270.0  11937.516667
# u17     103950.0  11474.466667
# u03     103158.0   9067.133333
# u52     105732.0   7006.616667

# %% [markdown]
# U1 with the most time on the call and U52 with the least time on the call

# %% [markdown]
# # Task 9.2 - Inter Corelation Coefficient and TimeSeries Analysis : S2 Sample

# %%
from pandas.io import gbq
from matplotlib import pyplot as plt
import pandas as pd

# %%
import sys
print(sys.getrecursionlimit())
# Out:
# 1000

# %%
df_sms_in_freq = gbq.read_gbq('select userid, sums_24hours as SMS_IN_FREQ from Students.S2_sms_in_freq',project_id='ipads2020-assignment9')
df_sms_in_len = gbq.read_gbq('select  userid, sums_24hours as SMS_IN_LEN from Students.S2_sms_in_len',project_id='ipads2020-assignment9')
df_sms_out_freq = gbq.read_gbq('select  userid, sums_24hours as SMS_OUT_FREQ from Students.S2_sms_out_freq',project_id='ipads2020-assignment9')
df_sms_out_len = gbq.read_gbq('select  userid, sums_24hours as SMS_OUT_LEN from Students.S2_sms_out_len',project_id='ipads2020-assignment9')
df_call_out_freq = gbq.read_gbq('select  userid, sums_24hours as CALL_OUT_FREQ from Students.S2_call_out_freq',project_id='ipads2020-assignment9')
df_call_out_len = gbq.read_gbq('select  userid, sums_24hours as CALL_OUT_LEN from Students.S2_call_out_len',project_id='ipads2020-assignment9')
df_call_in_freq = gbq.read_gbq('select  userid, sums_24hours as CALL_IN_FREQ from Students.S2_call_in_freq',project_id='ipads2020-assignment9')
df_call_in_len = gbq.read_gbq('select  userid, sums_24hours as CALL_IN_LEN from Students.S2_call_in_len',project_id='ipads2020-assignment9')
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=725825577420-unm2gnkiprugilg743tkbig250f4sfsj.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=yuLydF1dPk7HWZuzHY1bOMprqUE1xq&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AY0e-g6_IzxyKDrKBSfzcuaZf-GNco0L5jfXPTldmyXrye-guPD2sTgn9J0

# %%
df_sms_in_freq.head()
# Out:
#    userid SMS_IN_FREQ
# 0  585281           0
# 1  277259           0
# 2  634980           0
# 3  553102           0
# 4  785065           0

# %%
df_call_in_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   userid        350 non-null    int64
#  1   CALL_IN_FREQ  350 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 5.6+ KB

# %%
set_df=['df_call_in_freq','df_call_out_freq','df_call_in_len','df_call_out_len','df_sms_in_freq','df_sms_out_freq','df_sms_in_len','df_sms_out_len']

# %%
df_call_in_freq.replace('NA',  0, inplace=True)
df_call_in_freq['CALL_IN_FREQ']=df_call_in_freq.CALL_IN_FREQ.astype('int64')

df_call_in_len.replace('NA',  0, inplace=True)
df_call_in_len['CALL_IN_LEN']=df_call_in_len.CALL_IN_LEN.astype('int64')

df_call_out_freq.replace('NA',  0, inplace=True)
df_call_out_freq['CALL_OUT_FREQ']=df_call_out_freq.CALL_OUT_FREQ.astype('int64')

df_call_out_len.replace('NA',  0, inplace=True)
df_call_out_len['CALL_OUT_LEN']=df_call_out_len.CALL_OUT_LEN.astype('int64')


df_sms_in_freq.replace('NA',  0, inplace=True)
df_sms_in_freq['SMS_IN_FREQ']=df_sms_in_freq.SMS_IN_FREQ.astype('int64')
   
df_sms_in_len.replace('NA',  0, inplace=True)
df_sms_in_len['SMS_IN_LEN']=df_sms_in_len.SMS_IN_LEN.astype('int64')
   
df_sms_out_freq.replace('NA',  0, inplace=True)
df_sms_out_freq['SMS_OUT_FREQ']=df_sms_out_freq.SMS_OUT_FREQ.astype('int64')
   
df_sms_out_len.replace('NA',  0, inplace=True)
df_sms_out_len['SMS_OUT_LEN']=df_sms_out_len.SMS_OUT_LEN.astype('int64')

# %%
df_sms_out_freq
# Out:
#      userid  SMS_OUT_FREQ
# 0    585281             0
# 1    263696             0
# 2    277259             0
# 3    634980             0
# 4    553102             0
# ..      ...           ...
# 331  788976             0
# 332  921119             0
# 333  673698             1
# 334  921119             2
# 335  788976             4
#
# [336 rows x 2 columns]

# %%
pip install rpy2
# Out:
# Requirement already satisfied: rpy2 in /usr/local/lib/python3.6/dist-packages (3.2.7)
# Requirement already satisfied: simplegeneric in /usr/local/lib/python3.6/dist-packages (from rpy2) (0.8.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from rpy2) (3.6.4)
# Requirement already satisfied: cffi>=1.13.1 in /usr/local/lib/python3.6/dist-packages (from rpy2) (1.14.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from rpy2) (2018.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from rpy2) (2.11.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.6/dist-packages (from rpy2) (1.5.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest->rpy2) (1.15.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->rpy2) (8.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->rpy2) (51.1.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->rpy2) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->rpy2) (20.3.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->rpy2) (1.10.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->rpy2) (0.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.13.1->rpy2) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->rpy2) (1.1.1)

# %%
import rpy2 as ro
from rpy2.robjects import DataFrame, IntVector,FloatVector, pandas2ri
from rpy2.robjects.packages import importr
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
import rpy2 as ro

# %%
package_name="ICC"
ro.robjects.r(f'install.packages("{package_name}")')
pkg=importr(package_name)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/ICC_2.3.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 7352 bytes
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 7352 bytes
#
#
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/tmp/Rtmp5bFTNG/downloaded_packages’
# R[write to console]:
# R[write to console]:

# %%
def cal_icc():
  r_icc = importr("ICC")
  #def_res[]
  j=0
  set_df=['df_call_in_freq','df_call_out_freq','df_call_in_len','df_call_out_len','df_sms_in_freq','df_sms_out_freq','df_sms_in_len','df_sms_out_len']
  for i in df_call_in_freq,df_call_out_freq,df_call_in_len,df_call_out_len,df_sms_in_freq,df_sms_out_freq,df_sms_in_len,df_sms_out_len :
    df = i
    groups=df['userid'].to_list()
    values=df.iloc[:,1].to_list()
    #print(type(i))
    r_icc = importr("ICC")
    df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
    icc_res = r_icc.ICCbare("groups", "values", data=df)
    icc_val = icc_res[0] 
    icc_res1=r_icc.ICCest("groups", "values", data=df)
    icc_res1
    #print( icc_res1)
    #icc_df = pandas2ri.rpy2py(icc[0])
    print(set_df[j])
    print("ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )
    j=j+1

# %%
cal_icc()
# Out:
# df_call_in_freq
# ICC:[1] 0.1115708
# Lower ICC :[1] 0.04356998
# Upper ICC :[1] 0.2397746
#
# df_call_out_freq
# ICC:[1] 0.1944612
# Lower ICC :[1] 0.1025994
# Upper ICC :[1] 0.3518347
#
# df_call_in_len
# ICC:[1] 0.1060321
# Lower ICC :[1] 0.03976695
# Upper ICC :[1] 0.2317776
#
# df_call_out_len
# ICC:[1] 0.1464291
# Lower ICC :[1] 0.06790283
# Upper ICC :[1] 0.2885876
#
# df_sms_in_freq
# ICC:[1] 0.39286
# Lower ICC :[1] 0.2598036
# Upper ICC :[1] 0.5768427
#
# df_sms_out_freq
# ICC:[1] 0.3549673
# Lower ICC :[1] 0.227266
# Upper ICC :[1] 0.5391687
#
# df_sms_in_len
# ICC:[1] 0.3001231
# Lower ICC :[1] 0.1821257
# Upper ICC :[1] 0.4811719
#
# df_sms_out_len
# ICC:[1] 0.3347373
# Lower ICC :[1] 0.2103536
# Upper ICC :[1] 0.5182721

# %% [markdown]
# ## Create a visualization of a user’s time-series for a particular measurement (e.g. CALL IN FREQ) that shows a large variance and one for another user that shows a small variance.

# %%
df_s2_call_in_freq = gbq.read_gbq('select * from Students.S2_call_in_freq',project_id='ipads2020-assignment9')

# %%
df_s2_call_in_freq.head()
# Out:
#    int64_field_0  userid      date sums_24hours
# 0              1  585281  20160523            0
# 1             29  263696  20160523            0
# 2             57  277259  20160523            0
# 3             85  655728  20160523            0
# 4            113  634980  20160523            0

# %%
from datetime import datetime

df_s2_call_in_freq['date'] = pd.to_datetime(df_s2_call_in_freq['date'], format='%Y%m%d').dt.strftime("%Y-%m-%d")

# %%
df_s2_call_in_freq.head()
# Out:
#    int64_field_0  userid        date sums_24hours
# 0              1  585281  2016-05-23            0
# 1             29  263696  2016-05-23            0
# 2             57  277259  2016-05-23            0
# 3             85  655728  2016-05-23            0
# 4            113  634980  2016-05-23            0

# %%
df_s2_call_in_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   int64_field_0  350 non-null    int64
#  1   userid         350 non-null    int64
#  2   date           350 non-null    object
#  3   sums_24hours   350 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 11.1+ KB

# %%
df_s2_call_in_freq.sums_24hours.replace('NA',  0, inplace=True)

# %%
df_s2_call_in_freq['sums_24hours']=df_s2_call_in_freq['sums_24hours'].astype('int64')

# %%
df_s2_call_in_freq['userid'].value_counts()
# Out:
# 823280    14
# 661250    14
# 263696    14
# 656423    14
# 585281    14
# 634980    14
# 879752    14
# 553102    14
# 785065    14
# 658607    14
# 763609    14
# 330987    14
# 268548    14
# 100333    14
# 277259    14
# 836905    14
# 623456    14
# 788976    14
# 655728    14
# 892814    14
# 774556    14
# 673698    14
# 173512    14
# 938972    14
# 348681    14
# Name: userid, dtype: int64

# %%
df_s2_var = df_s2_call_in_freq[['userid','sums_24hours']]

# %%
df_s2_var.groupby("userid").var().sort_values(by='sums_24hours', ascending=False)
# Out:
#         sums_24hours
# userid
# 173512      5.170330
# 774556      2.747253
# 785065      2.373626
# 658607      1.296703
# 268548      0.884615
# 100333      0.879121
# 656423      0.725275
# 277259      0.708791
# 823280      0.686813
# 938972      0.571429
# 263696      0.571429
# 763609      0.285714
# 623456      0.285714
# 348681      0.219780
# 673698      0.219780
# 634980      0.219780
# 661250      0.181319
# 892814      0.181319
# 585281      0.131868
# 836905      0.131868
# 879752      0.131868
# 655728      0.131868
# 788976      0.071429
# 553102      0.071429
# 330987      0.000000

# %% [markdown]
# ### studentid 173512 - high variacn	5.170330
# ### studentid 553102 - low variacn	0.071429

# %%
data_u1=df_s2_call_in_freq.query('userid== 173512')

data_u2=df_s2_call_in_freq.query('userid == 553102')

# %%
data_u1.head()
# Out:
#      int64_field_0  userid        date  sums_24hours
# 12             337  173512  2016-05-23             0
# 35             338  173512  2016-05-24             1
# 58             339  173512  2016-05-25             1
# 85             340  173512  2016-05-26             1
# 106            341  173512  2016-05-27             1

# %%
data_u2.head()
# Out:
#     int64_field_0  userid        date  sums_24hours
# 7             197  553102  2016-05-23             0
# 23            198  553102  2016-05-24             0
# 57            199  553102  2016-05-25             1
# 68            200  553102  2016-05-26             0
# 92            201  553102  2016-05-27             0

# %%
#userid 173512
data_u1 = [data_u1["date"], data_u1["sums_24hours"]]
headers = ["ds", "y"]
df_u1 = pd.concat(data_u1, axis=1, keys=headers)


#userid 553102
data_u2 = [data_u2["date"], data_u2["sums_24hours"]]
headers = ["ds", "y"]
df_u2 = pd.concat(data_u2, axis=1, keys=headers)

# %%
df_u1.head()
# Out:
#              ds  y
# 12   2016-05-23  0
# 35   2016-05-24  1
# 58   2016-05-25  1
# 85   2016-05-26  1
# 106  2016-05-27  1

# %%
df_u2.head()
# Out:
#             ds  y
# 7   2016-05-23  0
# 23  2016-05-24  0
# 57  2016-05-25  1
# 68  2016-05-26  0
# 92  2016-05-27  0

# %%
from fbprophet import Prophet
m1 = Prophet()
m1.fit(df_u1)

future1 = m1.make_future_dataframe(periods=30)
future1.tail()

forecast1 = m1.predict(future1)
#forecast1[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

fig1 = m1.plot(forecast1)

fig2 = m1.plot_components(forecast1)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 10.

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m1, forecast1)

plot_components_plotly(m1, forecast1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="468989b9-d98b-4a2a-b37b-f12cae9895e4" class="plotly-graph-div" style="height:200px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("468989b9-d98b-4a2a-b37b-f12cae9895e4")) {
#                     Plotly.newPlot(
#                         '468989b9-d98b-4a2a-b37b-f12cae9895e4',
#                         [{"line": {"color": "#0072B2", "width": 2}, "mode": "lines", "name": "trend", "type": "scatter", "x": ["2016-05-23T00:00:00", "2016-05-24T00:00:00", "2016-05-25T00:00:00", "2016-05-26T00:00:00", "2016-05-27T00:00:00", "2016-05-28T00:00:00", "2016-05-29T00:00:00", "2016-05-30T00:00:00", "2016-05-31T00:00:00", "2016-06-01T00:00:00", "2016-06-02T00:00:00", "2016-06-03T00:00:00", "2016-06-04T00:00:00", "2016-06-05T00:00:00", "2016-06-06T00:00:00", "2016-06-07T00:00:00", "2016-06-08T00:00:00", "2016-06-09T00:00:00", "2016-06-10T00:00:00", "2016-06-11T00:00:00", "2016-06-12T00:00:00", "2016-06-13T00:00:00", "2016-06-14T00:00:00", "2016-06-15T00:00:00", "2016-06-16T00:00:00", "2016-06-17T00:00:00", "2016-06-18T00:00:00", "2016-06-19T00:00:00", "2016-06-20T00:00:00", "2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-25T00:00:00", "2016-06-26T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-02T00:00:00", "2016-07-03T00:00:00", "2016-07-04T00:00:00", "2016-07-05T00:00:00"], "xaxis": "x", "y": [0.7107151163793848, 0.853713402117811, 0.9967116877004482, 1.1397099728766813, 1.2827082584257923, 1.4257065443804051, 1.5687048308424338, 1.7117031169658241, 1.854701402783297, 1.9976996880844884, 2.1406979738307936, 2.2836962591530727, 2.426694544475352, 2.5696928297976314, 2.7126911151199105, 2.8556894004421896, 2.9986876857644695, 3.1416859710867486, 3.284684256409028, 3.4276825417313073, 3.5706808270535872, 3.7136791123758663, 3.8566773976981454, 3.999675683020425, 4.142673968342705, 4.285672253664984, 4.428670538987263, 4.571668824309543, 4.714667109631821, 4.857665394954101, 5.00066368027638, 5.14366196559866, 5.286660250920939, 5.429658536243218, 5.572656821565497, 5.715655106887777, 5.858653392210056, 6.001651677532336, 6.144649962854614, 6.287648248176894, 6.430646533499174, 6.573644818821452, 6.716643104143732, 6.859641389466011], "yaxis": "y"}, {"line": {"color": "rgba(0, 114, 178, 0.2)", "width": 0}, "mode": "lines", "name": "trend_upper", "type": "scatter", "x": ["2016-05-23T00:00:00", "2016-05-24T00:00:00", "2016-05-25T00:00:00", "2016-05-26T00:00:00", "2016-05-27T00:00:00", "2016-05-28T00:00:00", "2016-05-29T00:00:00", "2016-05-30T00:00:00", "2016-05-31T00:00:00", "2016-06-01T00:00:00", "2016-06-02T00:00:00", "2016-06-03T00:00:00", "2016-06-04T00:00:00", "2016-06-05T00:00:00", "2016-06-06T00:00:00", "2016-06-07T00:00:00", "2016-06-08T00:00:00", "2016-06-09T00:00:00", "2016-06-10T00:00:00", "2016-06-11T00:00:00", "2016-06-12T00:00:00", "2016-06-13T00:00:00", "2016-06-14T00:00:00", "2016-06-15T00:00:00", "2016-06-16T00:00:00", "2016-06-17T00:00:00", "2016-06-18T00:00:00", "2016-06-19T00:00:00", "2016-06-20T00:00:00", "2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-25T00:00:00", "2016-06-26T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-02T00:00:00", "2016-07-03T00:00:00", "2016-07-04T00:00:00", "2016-07-05T00:00:00"], "xaxis": "x", "y": [0.7107151163793848, 0.853713402117811, 0.9967116877004482, 1.1397099728766813, 1.2827082584257923, 1.4257065443804051, 1.5687048308424338, 1.7117031169658241, 1.854701402783297, 1.9976996880844884, 2.1406979738307936, 2.2836962591530727, 2.426694544475352, 2.5696928297976314, 2.7126911191727534, 2.855689414967585, 2.998687715198228, 3.1416860181997057, 3.284684321928379, 3.42768262780373, 3.570680934720047, 3.71367924536464, 3.8566775568783918, 3.9996758707026077, 4.142674183948818, 4.285672502041337, 4.428670827529626, 4.5716691445396025, 4.714667470326742, 4.857665794371164, 5.000664120926836, 5.143662450464285, 5.286660779638575, 5.429659115597279, 5.572657448255825, 5.715655788452423, 5.858654113664384, 6.001652449529508, 6.1446507880739265, 6.28764912366691, 6.4306474614844555, 6.5736457970798545, 6 ...
#                         {"height": 200, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd

# %%
m2 = Prophet()
m2.fit(df_u2)

future2 = m2.make_future_dataframe(periods=30)
future2.tail()

forecast2 = m2.predict(future2)
#forecast2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

fig1 = m2.plot(forecast2)

fig2 = m2.plot_components(forecast2)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 10.

# %%
from fbprophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m2, forecast2)

plot_components_plotly(m2, forecast2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cc102482-db0b-4b60-ba4c-f5a1c203ef7d" class="plotly-graph-div" style="height:200px; width:900px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cc102482-db0b-4b60-ba4c-f5a1c203ef7d")) {
#                     Plotly.newPlot(
#                         'cc102482-db0b-4b60-ba4c-f5a1c203ef7d',
#                         [{"line": {"color": "#0072B2", "width": 2}, "mode": "lines", "name": "trend", "type": "scatter", "x": ["2016-05-23T00:00:00", "2016-05-24T00:00:00", "2016-05-25T00:00:00", "2016-05-26T00:00:00", "2016-05-27T00:00:00", "2016-05-28T00:00:00", "2016-05-29T00:00:00", "2016-05-30T00:00:00", "2016-05-31T00:00:00", "2016-06-01T00:00:00", "2016-06-02T00:00:00", "2016-06-03T00:00:00", "2016-06-04T00:00:00", "2016-06-05T00:00:00", "2016-06-06T00:00:00", "2016-06-07T00:00:00", "2016-06-08T00:00:00", "2016-06-09T00:00:00", "2016-06-10T00:00:00", "2016-06-11T00:00:00", "2016-06-12T00:00:00", "2016-06-13T00:00:00", "2016-06-14T00:00:00", "2016-06-15T00:00:00", "2016-06-16T00:00:00", "2016-06-17T00:00:00", "2016-06-18T00:00:00", "2016-06-19T00:00:00", "2016-06-20T00:00:00", "2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-25T00:00:00", "2016-06-26T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-02T00:00:00", "2016-07-03T00:00:00", "2016-07-04T00:00:00", "2016-07-05T00:00:00"], "xaxis": "x", "y": [0.20171889749301514, 0.18188277027413885, 0.16204664293335042, 0.14221051565652876, 0.12237438816790634, 0.1025382606481378, 0.08270213328721371, 0.06286600602865472, 0.04302987877641662, 0.02319375130447779, 0.003357623679787647, -0.016478503804771838, -0.03631463128933138, -0.05615075877389086, -0.07598688625845035, -0.09582301374300983, -0.11565914122756943, -0.1354952687121289, -0.1553313961966884, -0.17516752368124788, -0.19500365116580748, -0.21483977865036696, -0.23467590613492645, -0.25451203361948593, -0.27434816110404553, -0.294184288588605, -0.3140204160731645, -0.33385654355772404, -0.35369267104228347, -0.373528798526843, -0.39336492601140244, -0.4132010534959621, -0.43303718098052163, -0.45287330846508106, -0.4727094359496406, -0.49254556343420014, -0.5123816909187595, -0.532217818403319, -0.5520539458878786, -0.5718900733724381, -0.5917262008569977, -0.6115623283415572, -0.6313984558261168, -0.6512345833106761], "yaxis": "y"}, {"line": {"color": "rgba(0, 114, 178, 0.2)", "width": 0}, "mode": "lines", "name": "trend_upper", "type": "scatter", "x": ["2016-05-23T00:00:00", "2016-05-24T00:00:00", "2016-05-25T00:00:00", "2016-05-26T00:00:00", "2016-05-27T00:00:00", "2016-05-28T00:00:00", "2016-05-29T00:00:00", "2016-05-30T00:00:00", "2016-05-31T00:00:00", "2016-06-01T00:00:00", "2016-06-02T00:00:00", "2016-06-03T00:00:00", "2016-06-04T00:00:00", "2016-06-05T00:00:00", "2016-06-06T00:00:00", "2016-06-07T00:00:00", "2016-06-08T00:00:00", "2016-06-09T00:00:00", "2016-06-10T00:00:00", "2016-06-11T00:00:00", "2016-06-12T00:00:00", "2016-06-13T00:00:00", "2016-06-14T00:00:00", "2016-06-15T00:00:00", "2016-06-16T00:00:00", "2016-06-17T00:00:00", "2016-06-18T00:00:00", "2016-06-19T00:00:00", "2016-06-20T00:00:00", "2016-06-21T00:00:00", "2016-06-22T00:00:00", "2016-06-23T00:00:00", "2016-06-24T00:00:00", "2016-06-25T00:00:00", "2016-06-26T00:00:00", "2016-06-27T00:00:00", "2016-06-28T00:00:00", "2016-06-29T00:00:00", "2016-06-30T00:00:00", "2016-07-01T00:00:00", "2016-07-02T00:00:00", "2016-07-03T00:00:00", "2016-07-04T00:00:00", "2016-07-05T00:00:00"], "xaxis": "x", "y": [0.20171889749301514, 0.18188277027413885, 0.16204664293335042, 0.14221051565652876, 0.12237438816790634, 0.10253826064813781, 0.08270213328721371, 0.06286600602865472, 0.04302987877641662, 0.02319375130447779, 0.003357623679787647, -0.016478503804771838, -0.03631463128933138, -0.05615075877389086, -0.07598688581645974, -0.09582301213009392, -0.1156591379618036, -0.1354952633605998, -0.15533138877296382, -0.17516751331929456, -0.1950036375146671, -0.21483976215306647, -0.2346758857502637, -0.2545120103103742, -0.2743481335664617, -0.2941842566475794, -0.3140203801887124, -0.33385650294515556, -0.3536926256831441, -0.3735287493288303, -0.39336487284345645, -0.413200996604348, -0.4330371198070745, -0.4528732429105926, -0. ...
#                         {"height": 200, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0,

# %% [markdown]
# #Task 9.3 - Finding Corelation between Behaviour and Personality

# %%
df_s3 = gbq.read_gbq('select * from Students.S3_social_behaviour',project_id='ipads2020-assignment9')

# %%
df_s3.head()
# Out:
#    int64_field_0  userid  call_out_num_avg_daily  ...  BFSI_E  BFSI_A  BFSI_N
# 0              8   17399                0.000000  ...  0.5066 -0.8064  0.8745
# 1              9   18336                0.000000  ... -0.0090 -0.0711  0.3583
# 2             10   18818                0.034483  ...  0.4861  0.7732 -0.7022
# 3             15   20439                0.033333  ... -0.1673 -0.1943 -0.3104
# 4             16   22271                0.000000  ... -0.4207 -0.3580  0.2921
#
# [5 rows x 205 columns]

# %%
r_icc = importr("ICC")
  #def_res[]
  #set_df=['df_call_in_freq','df_call_out_freq','df_call_in_len','df_call_out_len','df_sms_in_freq','df_sms_out_freq','df_sms_in_len','df_sms_out_len']
  #for i in df_call_in_freq,df_call_out_freq,df_call_in_len,df_call_out_len,df_sms_in_freq,df_sms_out_freq,df_sms_in_len,df_sms_out_len :
   # df = i
groups=df_s3['call_out_dur_avg_daily'].to_list()
values=df_s3['BFSI_E'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL OUT DUR Extraversion ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_out_dur_avg_daily'].to_list()
values=df_s3['BFSI_O'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL OUT DUR openness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_out_dur_avg_daily'].to_list()
values=df_s3['BFSI_C'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL OUT DUR conscientiousness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_out_dur_avg_daily'].to_list()
values=df_s3['BFSI_A'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL OUT DUR agreeableness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_out_dur_avg_daily'].to_list()
values=df_s3['BFSI_N'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
print("Daily CALL OUT DUR  neuroticism ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )
# Out:
# Daily CALL OUT DUR Extraversion ICC:[1] -0.05082625
# Lower ICC :[1] -0.4449291
# Upper ICC :[1] 0.2587485
#
# Daily CALL OUT DUR openness ICC:[1] -0.367005
# Lower ICC :[1] -0.7814345
# Upper ICC :[1] -0.007952622
#
# Daily CALL OUT DUR conscientiousness ICC:[1] 0.148483
# Lower ICC :[1] -0.2130452
# Upper ICC :[1] 0.4153091
#
# Daily CALL OUT DUR agreeableness ICC:[1] 0.1350457
# Lower ICC :[1] -0.2292025
# Upper ICC :[1] 0.4050161
#
# Daily CALL OUT DUR  neuroticism ICC:[1] -0.2569622
# Lower ICC :[1] -0.6683824
# Upper ICC :[1] 0.08756804

# %%
r_icc = importr("ICC")
  #def_res[]
  #set_df=['df_call_in_freq','df_call_out_freq','df_call_in_len','df_call_out_len','df_sms_in_freq','df_sms_out_freq','df_sms_in_len','df_sms_out_len']
  #for i in df_call_in_freq,df_call_out_freq,df_call_in_len,df_call_out_len,df_sms_in_freq,df_sms_out_freq,df_sms_in_len,df_sms_out_len :
   # df = i
groups=df_s3['call_in_dur_avg_daily'].to_list()
values=df_s3['BFSI_E'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL IN DUR Extraversion ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_in_dur_avg_daily'].to_list()
values=df_s3['BFSI_O'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL IN DUR openness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_in_dur_avg_daily'].to_list()
values=df_s3['BFSI_C'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL IN DUR conscientiousness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_in_dur_avg_daily'].to_list()
values=df_s3['BFSI_A'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily CALL IN DUR agreeableness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['call_in_dur_avg_daily'].to_list()
values=df_s3['BFSI_N'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
print("Daily CALL IN DUR  neuroticism ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )
# Out:
# Daily CALL IN DUR Extraversion ICC:[1] -0.3457488
# Lower ICC :[1] -0.7677827
# Upper ICC :[1] 0.01497609
#
# Daily CALL IN DUR openness ICC:[1] -0.2941983
# Lower ICC :[1] -0.714321
# Upper ICC :[1] 0.05939391
#
# Daily CALL IN DUR conscientiousness ICC:[1] 0.06655132
# Lower ICC :[1] -0.3135421
# Upper ICC :[1] 0.3535099
#
# Daily CALL IN DUR agreeableness ICC:[1] 0.1568647
# Lower ICC :[1] -0.2052632
# Upper ICC :[1] 0.4228592
#
# Daily CALL IN DUR  neuroticism ICC:[1] -0.1955795
# Lower ICC :[1] -0.6095069
# Upper ICC :[1] 0.1426439

# %%
r_icc = importr("ICC")
  #def_res[]
  #set_df=['df_call_in_freq','df_call_out_freq','df_call_in_len','df_call_out_len','df_sms_in_freq','df_sms_out_freq','df_sms_in_len','df_sms_out_len']
  #for i in df_call_in_freq,df_call_out_freq,df_call_in_len,df_call_out_len,df_sms_in_freq,df_sms_out_freq,df_sms_in_len,df_sms_out_len :
   # df = i
groups=df_s3['sms_in_num_avg_daily'].to_list()
values=df_s3['BFSI_E'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily SMS IN NUM Extraversion ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['sms_in_num_avg_daily'].to_list()
values=df_s3['BFSI_O'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily SMS IN NUM openness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['sms_in_num_avg_daily'].to_list()
values=df_s3['BFSI_C'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily SMS IN NUM conscientiousness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['sms_in_num_avg_daily'].to_list()
values=df_s3['BFSI_A'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
#print( icc_res[0])
    #icc_df = pandas2ri.rpy2py(icc[0])
    #print(set_df[j])
print("Daily SMS IN NUM agreeableness ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )

groups=df_s3['sms_in_num_avg_daily'].to_list()
values=df_s3['BFSI_N'].to_list()
    #print(type(i))
r_icc = importr("ICC")
df = DataFrame({"groups": IntVector(groups),
               "values": FloatVector(values)})
icc_res = r_icc.ICCbare("groups", "values", data=df)
icc_val = icc_res[0] 
icc_res1=r_icc.ICCest("groups", "values", data=df)
icc_res1
print("Daily SMS IN NUM  neuroticism ICC:"+ str(icc_res1[0])+"Lower ICC :" + str(icc_res1[1])+ "Upper ICC :"+str(icc_res1[2])  )
# Out:
# Daily SMS IN NUM Extraversion ICC:[1] -0.02712702
# Lower ICC :[1] -0.07489065
# Upper ICC :[1] 0.1544323
#
# Daily SMS IN NUM openness ICC:[1] 0.06718044
# Lower ICC :[1] -0.02747302
# Upper ICC :[1] 0.3545156
#
# Daily SMS IN NUM conscientiousness ICC:[1] 0.09117272
# Lower ICC :[1] -0.01460414
# Upper ICC :[1] 0.3956336
#
# Daily SMS IN NUM agreeableness ICC:[1] 0.050627
# Lower ICC :[1] -0.0361532
# Upper ICC :[1] 0.3241456
#
# Daily SMS IN NUM  neuroticism ICC:[1] -0.03156072
# Lower ICC :[1] -0.07700371
# Upper ICC :[1] 0.1431406

# %% [markdown]
# #Task 9.4 - Predicting Individuals Personality

# %%
df_s3_social_behaviors = gbq.read_gbq('select * from Students.S3_social_behaviour',project_id='ipads2020-assignment9')

# %%
df_s3_social_behaviors.shape
# Out:
# (137, 205)

# %%
df_s3_social_behaviors
# Out:
#      int64_field_0  userid  call_out_num_avg_daily  ...  BFSI_E  BFSI_A  BFSI_N
# 0                8   17399                0.000000  ...  0.5066 -0.8064  0.8745
# 1                9   18336                0.000000  ... -0.0090 -0.0711  0.3583
# 2               10   18818                0.034483  ...  0.4861  0.7732 -0.7022
# 3               15   20439                0.033333  ... -0.1673 -0.1943 -0.3104
# 4               16   22271                0.000000  ... -0.4207 -0.3580  0.2921
# 5               18   23429                0.000000  ...  0.1202  0.5388 -0.0578
# 6               24   25835                0.033333  ... -0.3042  0.1372  0.8701
# 7               29   28017                0.033333  ... -0.7105 -0.0816  0.1301
# 8               31   28923                0.033333  ... -0.0139 -0.4345 -0.5131
# 9               32   30645                0.033333  ...  0.5896 -0.8064 -1.2249
# 10              33   30932                0.033333  ...  0.3116 -0.3513  0.8678
# 11              36   32944                0.033333  ... -0.4987 -0.3466  0.2227
# 12              37   33992                0.033333  ...  1.3308  0.7418 -0.9286
# 13              43   36482                0.033333  ...  1.5174  0.8568 -0.2485
# 14              44   36803                0.033333  ...  0.4459  1.4299 -1.0689
# 15              45   37106                0.033333  ... -0.4538 -0.3979  0.2838
# 16              51   38841                0.033333  ... -0.1890  0.3804  0.8097
# 17              57   42719                0.066667  ...  0.2496 -0.3595  0.1270
# 18              58   43225                0.000000  ...  1.1506  1.1220  0.0109
# 19              65   47704                0.370370  ... -1.0883 -0.5941  0.0901
# 20              68   48290                0.033333  ...  1.1019 -1.2450 -0.5762
# 21              70   50708                0.034483  ... -1.9760 -0.3104  1.9955
# 22              73   53122                0.033333  ...  0.0131  0.6947 -0.6027
# 23              76   56351                0.033333  ... -1.0514  0.2736  0.8136
# 24              78   58173                0.033333  ...  0.4585  0.8024  0.3596
# 25              87   67671                0.033333  ...  0.3873 -0.1562  0.7211
# 26              89   67851                0.033333  ... -0.1679 -0.7287  0.6418
# 27              90   69148                0.033333  ...  0.1435 -0.3104  0.2850
# 28              92   71826                0.033333  ...  0.2571 -0.7242 -0.3624
# 29              95   73284                0.033333  ... -1.7403 -0.7546  0.9866
# 30              97   73968                0.058824  ...  1.4156  0.2126 -0.4907
# 31             104   78827                0.000000  ...  0.4948  0.5605  0.4094
# 32             106   79960                0.033333  ...  0.6032  0.2469 -0.4623
# 33             112   85351                0.033333  ...  1.2150  0.2822 -0.4215
# 34             114   88988                0.000000  ... -0.3395  0.3308 -0.0159
# 35             118   91689                0.000000  ... -1.0755 -0.8934  1.5660
# 36             136   97058                0.033333  ... -0.1296 -0.6276 -0.1081
# 37               2   11491                0.266667  ... -1.1607 -2.1099 -1.1622
# 38              34   32611                0.400000  ... -0.4810 -1.9340  0.7051
# 39              39   34745                0.000000  ... -0.3575 -0.2853 -0.1710
# 40              83   65400                0.200000  ...  0.3735 -0.0576  0.4887
# 41              81   62245                0.600000  ... -0.6752 -0.2450 -0.7803
# 42              80   61577                1.600000  ... -0.3048  0.5376 -0.3670
# 43              69   49459                0.566667  ...  0.8248 -0.9876 -0.2510
# 44              96   73858                0.700000  ... -0.9128 -0.0184  1.1705
# 45              71   51117                1.266667  ...  0.1131 -1.7899 -0.4933
# 46              50   38334                0.466667  ... -0.7047  0.4948 -0.8088
# 47             110   82288                0.666667  ... -0.5109  0.5479 -0.1254
# 48              98   74356                0.233333  ...  0.1005 -1.1705 -0.2729
# 49              12   19612                0.333333  ...  0.2438  0.3805 -1.2184
# 50              53   39750                0.433333  ... -1.5658 -0.9255  0.9453
# 51              91   71825                0.066667  ... -0.7452  0.1857  0.5454
# 52             105   79050                0.714286  ... -0.5252 -0.4115 -0.8788
# 53             121   93127                3.866667  ... -0.0391 -0.2393  0.9162
# 54              88   67826                0.566667  ... -0.1509  0.1776 -0.4865
# 55              67   48097                4.500000  ...  0.5429 -0.7836 -0.0697
# 56             113   87358                0.533333  ...  1.7100  1.8009 -2.5201
# 57               3   12552                0.566667  ... -0.2877 -0.1796  1.6827
# 58              85   65493                3.866667  ...  0.1029  0.6758 -0.2100
# 59              19   23439                3.766667  ...  1.8134  0.3358  0.1554
# 60             125   94406                1.866667  ... -0.1266 -0.3002  0.9458
# 61              13   20180                1.700000  ... -0.0876 -0.5062  0.7997
# 62              35   32670                0.000000  ...  0.4199  0.1212 -0.2737
# 63              41   36099                0.033333  ... -0.3020 -0.1890  0.2251
# 64             115   89849                0.000000  ... -1.6782 -1.0734  0.4200
# 65             133   95933                0.000000  ... -0.7133 -0.1877  0.3998
# 66              77   57679                0.266667  ... -0.9546 -1.2251  0.6083
# 67              59   43639                1.083333  ...  0.4850 -0.2812 -1.1739
# 68             127   94601                0.766667  ... -0.5190 -0.5429 -0.9399
# 69              40   35018                1.633333  ...  0.3188 -0.1704  0.0757
# 70              54   39976                1.333333  ...  1.0249 -0.1781  0.0475
# 71              82   62574                1.200000  ...  0.0539  0.5197 -0.2139
# 72              66   47878                0.766667  ...  0.5911  0.3139 -0.8866
# 73              47   37480                0.600000  ... -0.1507 -0.9033  0.5264
# 74             109   81933                0.300000  ... -0.7023 -1.6789  0.3859
# 75              21   24761                0.933333  ... -0.6097 -0.8317 -0.0399
# 76              61   45244                0.533333  ... -0.4205  0.4405 -0.5817
# 77              60   44703                2.866667  ...  1.5418  1.0150 -1.3899
# 78              94   72706                1.033333  ... -0.2833  0.9425  0.6814
# 79              72   51247                0.633333  ... -0.1731  0.0463  0.0148
# 80             130   95470                2.000000  ...  1.1332  1.7466 -1.3524
# 81             135   96622                0.933333  ...  0.5488 -0.3952  0.9277
# 82             107   80202                1.433333  ...  0.6310  1.6678  0.0519
# 83             131   95538                7.600000  ...  0.0915  0.1261  0.4131
# 84              52   39133                0.966667  ... -0.6814  1.5504 -0.6756
# 85              30   28756                1.300000  ... -0.1242  0.2737  0.2914
# 86              48   37702                0.700000  ... -0.1619  0.1046  0.1349
# 87              46   37209                2.766667  ... -0.0720 -0.1468  0.2250
# 88             134   96502                1.466667  ... -0.3749 -0.5912  0.0749
# 89               7   15693                0.300000  ... -0.9906 -1.2005  1.4149
# 90             122   93654                0.866667  ... -0.3941  0.5678  1.0914
# 91              49   37705                0.566667  ...  0.7861 -0.0249  1.2234
# 92             111   83779                2.233333  ...  0.6448 -0.4934 -0.8899
# 93             119   91709                0.666667  ...  0.0233 -0.2352 -0.0700
# 94             117   91278                1.965517  ... -0.4658 -0.4062 -0.3004
# 95             120   92814                1.900000  ...  1.1473 -0.1024 -0.4913
# 96               6   14154                0.833333  ... -0.1213 -0.9829 -0.5203
# 97              79   58444                0.666667  ... -0.8661 -0.9867  0.1844
# 98              62   45452                1.000000  ... -1.1970  0.0271 -0.1680
# 99             100   77267                3.300000  ...  0.1859 -0.4958 -0.4044
# 100            116   90885                1.966667  ...  0.5906  1.0854 -0.7845
# 101             42   36144                8.100000  ... -0.3316 -0.4142  0.2662
# 102             86   67174                2.600000  ...  1.3940 -0.7315  0.2274
# 103            102   77873                2.333333  ... -0.7625 -0.5559  0.3929
# 104             56   41883                2.933333  ... -0.2597 -0.4688  1.5321
# 105             63   46655                1.066667  ...  0.4679  0.1948  0.2262
# 106             38   34196                3.166667  ... -0.1040 -0.9828  0.1549
# 107            101   77598                2.900000  ...  0.1149  1.7442  0.6915
# 108             93   71978                1.333333  ...  1.8764  0.6638 -0.5338
# 109            126   94479                6.066667  ... -0.0007 -0.1276 -0.4939
# 110            123   94005                5.800000  ...  0.2838  0.4979 -0.4445
# 111             84   65403                2.300000  ...  1.1272 -0.4152 -0.6847
# 112              1   11304                0.666667  ... -1.0278 -1.4482  0.9334
# 113            132   95904                0.733333  ...  0.3693 -0.3926 -0.5888
# 114             74   53503                4.333333  ... -0.4628 -1.4083  1.2092
# 115             28   27993                2.166667  ...  0.0733 -0.8045  0.0768
# 116            128   95152                0.000000  ...  0.2502  1.0393 -0.2777
# 117             17   22718                0.600000  ...  0.7477 -0.9170 -0.4077
# 118              5   13604                1.000000  ...  0.3674 -0.6329 -0.1927
# 119            108   81076                2.200000  ... -0.1341 -0.2242  0.1440
# 120             11   19533                2.400000  ...  0.7423  0.8434  0.5761
# 121             26   26192                0.300000  ... -0.6576 -0.3414 -0.0026
# 122             99   76030                0.333333  ... -0.6146 -1.4579  0.5337
# 123              4   13275                0.300000  ... -0.8416 -0.8495  0.8580
# 124             25   25870                1.833333  ...  0.0607 -0.3474  0.1372
# 125             27   26690                1.400000  ...  0.3846  0.3893 -0.2290
# 126            129   95295                0.133333  ... -0.4986  0.0317  1.0175
# 127             23   25495                1.033333  ...  0.6199 -1.0705 -0.7339
# 128             55   40864                2.333333  ...  0.8545 -0.1442 -0.4303
# 129             22   25282                0.633333  ...  0.5965 -0.0414 -0.1202
# 130            103   78794                2.933333  ...  0.0456  0.0234 -0.0324
# 131             14   20317                1.466667  ... -0.2683 -0.0071 -0.2102
# 132             20   23497                1.933333  ... -0.6034 -0.8169  0.4073
# 133             64   47702                1.566667  ...  0.0828 -0.1387  0.1752
# 134            137   99007                5.133333  ...  0.8106  0.1873 -0.0239
# 135            124   94115                5.500000  ...  1.1152 -0.7516  0.0240
# 136             75   54633                4.366667  ...  0.1472 -0.6465  0.0755
#
# [137 rows x 205 columns]

# %%
df_s3_social_behaviors.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 205 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   int64_field_0                       137 non-null    int64
#  1   userid                              137 non-null    int64
#  2   call_out_num_avg_daily              137 non-null    float64
#  3   call_out_dur_avg_daily              137 non-null    float64
#  4   call_out_num_avg_afternoon          137 non-null    float64
#  5   call_out_dur_avg_afternoon          137 non-null    float64
#  6   call_out_num_avg_evening            137 non-null    float64
#  7   call_out_dur_avg_evening            137 non-null    float64
#  8   call_out_num_avg_morning            137 non-null    float64
#  9   call_out_dur_avg_morning            137 non-null    float64
#  10  call_out_num_avg_night              137 non-null    float64
#  11  call_out_dur_avg_night              137 non-null    float64
#  12  call_in_num_avg_daily               137 non-null    float64
#  13  call_in_dur_avg_daily               137 non-null    float64
#  14  call_in_num_avg_afternoon           137 non-null    float64
#  15  call_in_dur_avg_afternoon           137 non-null    float64
#  16  call_in_num_avg_evening             137 non-null    float64
#  17  call_in_dur_avg_evening             137 non-null    float64
#  18  call_in_num_avg_morning             137 non-null    float64
#  19  call_in_dur_avg_morning             137 non-null    float64
#  20  call_in_num_avg_night               137 non-null    float64
#  21  call_in_dur_avg_night               137 non-null    float64
#  22  sms_in_num_avg_daily                137 non-null    float64
#  23  sms_out_num_avg_daily               137 non-null    float64
#  24  sms_in_len_avg_daily                137 non-null    float64
#  25  sms_out_len_avg_daily               137 non-null    float64
#  26  app_messaging_num_avg_daily         137 non-null    float64
#  27  app_social_num_avg_daily            137 non-null    float64
#  28  app_messaging_dur_avg_daily         137 non-null    float64
#  29  app_messaging_durRob_avg_daily      137 non-null    float64
#  30  app_social_dur_avg_daily            137 non-null    float64
#  31  app_social_durRob_avg_daily         137 non-null    float64
#  32  sms_in_num_avg_afternoon            137 non-null    float64
#  33  sms_out_num_avg_afternoon           137 non-null    float64
#  34  sms_in_len_avg_afternoon            137 non-null    float64
#  35  sms_out_len_avg_afternoon           137 non-null    float64
#  36  app_messaging_num_avg_afternoon     137 non-null    float64
#  37  app_social_num_avg_afternoon        137 non-null    float64
#  38  app_messaging_dur_avg_afternoon     137 non-null    float64
#  39  app_messaging_durRob_avg_afternoon  137 non-null    float64
#  40  app_social_dur_avg_afternoon        137 non-null    float64
#  41  app_social_durRob_avg_afternoon     137 non-null    float64
#  42  sms_in_num_avg_evening              137 non-null    float64
#  43  sms_out_num_avg_evening             137 non-null    float64
#  44  sms_in_len_avg_evening              137 non-null    float64
#  45  sms_out_len_avg_evening             137 non-null    float64
#  46  app_messaging_num_avg_evening       137 non-null    float64
#  47  app_social_num_avg_evening          137 non-null    float64
#  48  app_messaging_dur_avg_evening       137 non-null    float64
#  49  app_messaging_durRob_avg_evening    137 non-null    float64
#  50  app_social_dur_avg_evening          137 non-null    float64
#  51  app_social_durRob_avg_evening       137 non-null    float64
#  52  sms_in_num_avg_morning              137 non-null    float64
#  53  sms_out_num_avg_morning             137 non-null    float64
#  54  sms_in_len_avg_morning              137 non-null    float64
#  55  sms_out_len_avg_morning             137 non-null    float64
#  56  app_messaging_num_avg_morning       137 non-null    float64
#  57  app_social_num_avg_morning          137 non-null    float64
#  58  app_messaging_dur_avg_morning       137 non-null    float64
#  59  app_messaging_durRob_avg_morning    137 non-null    float64
#  60  app_social_dur_avg_morning          137 non-null    float64
#  61  app_social_durRob_avg_morning       137 non-null    float64
#  62  sms_in_num_avg_night                137 non-null    float64
#  63  sms_out_num_avg_night               137 non-null    float64
#  64  sms_in_len_avg_night                137 non-null    float64
#  65  sms_out_len_avg_night               137 non-null    float64
#  66  app_messaging_num_avg_night         137 non-null    float64
#  67  app_social_num_avg_night            137 non-null    float64
#  68  app_messaging_dur_avg_night         137 non-null    float64
#  69  app_messaging_durRob_avg_night      137 non-null    float64
#  70  app_social_dur_avg_night            137 non-null    float64
#  71  app_social_durRob_avg_night         137 non-null    float64
#  72  call_out_num_avg_weekends           137 non-null    float64
#  73  call_out_dur_avg_weekends           137 non-null    float64
#  74  call_in_num_avg_weekends            137 non-null    float64
#  75  call_in_dur_avg_weekends            137 non-null    float64
#  76  sms_in_num_avg_weekends             137 non-null    float64
#  77  sms_out_num_avg_weekends            137 non-null    float64
#  78  sms_in_len_avg_weekends             137 non-null    float64
#  79  sms_out_len_avg_weekends            137 non-null    float64
#  80  app_messaging_num_avg_weekends      137 non-null    float64
#  81  app_social_num_avg_weekends         137 non-null    float64
#  82  app_messaging_dur_avg_weekends      137 non-null    float64
#  83  app_messaging_durRob_avg_weekends   137 non-null    float64
#  84  app_social_dur_avg_weekends         137 non-null    float64
#  85  app_social_durRob_avg_weekends      137 non-null    float64
#  86  call_out_num_avg_weekdays           137 non-null    float64
#  87  call_out_dur_avg_weekdays           137 non-null    float64
#  88  call_in_num_avg_weekdays            137 non-null    float64
#  89  call_in_dur_avg_weekdays            137 non-null    float64
#  90  sms_in_num_avg_weekdays             137 non-null    float64
#  91  sms_out_num_avg_weekdays            137 non-null    float64
#  92  sms_in_len_avg_weekdays             137 non-null    float64
#  93  sms_out_len_avg_weekdays            137 non-null    float64
#  94  app_messaging_num_avg_weekdays      137 non-null    float64
#  95  app_social_num_avg_weekdays         137 non-null    float64
#  96  app_messaging_dur_avg_weekdays      137 non-null    float64
#  97  app_messaging_durRob_avg_weekdays   137 non-null    float64
#  98  app_social_dur_avg_weekdays         137 non-null    float64
#  99  app_social_durRob_avg_weekdays      137 non-null    float64
#  100 call_out_num_avg_monday             137 non-null    float64
#  101 call_out_dur_avg_monday             137 non-null    float64
#  102 call_in_num_avg_monday              137 non-null    float64
#  103 call_in_dur_avg_monday              137 non-null    float64
#  104 sms_in_num_avg_monday               137 non-null    float64
#  105 sms_out_num_avg_monday              137 non-null    float64
#  106 sms_in_len_avg_monday               137 non-null    float64
#  107 sms_out_len_avg_monday              137 non-null    float64
#  108 app_messaging_num_avg_monday        137 non-null    float64
#  109 app_social_num_avg_monday           137 non-null    float64
#  110 app_messaging_dur_avg_monday        137 non-null    float64
#  111 app_messaging_durRob_avg_monday     137 non-null    float64
#  112 app_social_dur_avg_monday           137 non-null    float64
#  113 app_social_durRob_avg_monday        137 non-null    float64
#  114 call_out_num_avg_tuesday            137 non-null    float64
#  115 call_out_dur_avg_tuesday            137 non-null    float64
#  116 call_in_num_avg_tuesday             137 non-null    float64
#  117 call_in_dur_avg_tuesday             137 non-null    float64
#  118 sms_in_num_avg_tuesday              137 non-null    float64
#  119 sms_out_num_avg_tuesday             137 non-null    float64
#  120 sms_in_len_avg_tuesday              137 non-null    float64
#  121 sms_out_len_avg_tuesday             137 non-null    float64
#  122 app_messaging_num_avg_tuesday       137 non-null    float64
#  123 app_social_num_avg_tuesday          137 non-null    float64
#  124 app_messaging_dur_avg_tuesday       137 non-null    float64
#  125 app_messaging_durRob_avg_tuesday    137 non-null    float64
#  126 app_social_dur_avg_tuesday          137 non-null    float64
#  127 app_social_durRob_avg_tuesday       137 non-null    float64
#  128 call_out_num_avg_wednesday          137 non-null    float64
#  129 call_out_dur_avg_wednesday          137 non-null    float64
#  130 call_in_num_avg_wednesday           137 non-null    float64
#  131 call_in_dur_avg_wednesday           137 non-null    float64
#  132 sms_in_num_avg_wednesday            137 non-null    float64
#  133 sms_out_num_avg_wednesday           137 non-null    float64
#  134 sms_in_len_avg_wednesday            137 non-null    float64
#  135 sms_out_len_avg_wednesday           137 non-null    float64
#  136 app_messaging_num_avg_wednesday     137 non-null    float64
#  137 app_social_num_avg_wednesday        137 non-null    float64
#  138 app_messaging_dur_avg_wednesday     137 non-null    float64
#  139 app_messaging_durRob_avg_wednesday  137 non-null    float64
#  140 app_social_dur_avg_wednesday        137 non-null    float64
#  141 app_social_durRob_avg_wednesday     137 non-null    float64
#  142 call_out_num_avg_thursday           137 non-null    float64
#  143 call_out_dur_avg_thursday           137 non-null    float64
#  144 call_in_num_avg_thursday            137 non-null    float64
#  145 call_in_dur_avg_thursday            137 non-null    float64
#  146 sms_in_num_avg_thursday             137 non-null    float64
#  147 sms_out_num_avg_thursday            137 non-null    float64
#  148 sms_in_len_avg_thursday             137 non-null    float64
#  149 sms_out_len_avg_thursday            137 non-null    float64
#  150 app_messaging_num_avg_thursday      137 non-null    float64
#  151 app_social_num_avg_thursday         137 non-null    float64
#  152 app_messaging_dur_avg_thursday      137 non-null    float64
#  153 app_messaging_durRob_avg_thursday   137 non-null    float64
#  154 app_social_dur_avg_thursday         137 non-null    float64
#  155 app_social_durRob_avg_thursday      137 non-null    float64
#  156 call_out_num_avg_friday             137 non-null    float64
#  157 call_out_dur_avg_friday             137 non-null    float64
#  158 call_in_num_avg_friday              137 non-null    float64
#  159 call_in_dur_avg_friday              137 non-null    float64
#  160 sms_in_num_avg_friday               137 non-null    float64
#  161 sms_out_num_avg_friday              137 non-null    float64
#  162 sms_in_len_avg_friday               137 non-null    float64
#  163 sms_out_len_avg_friday              137 non-null    float64
#  164 app_messaging_num_avg_friday        137 non-null    float64
#  165 app_social_num_avg_friday           137 non-null    float64
#  166 app_messaging_dur_avg_friday        137 non-null    float64
#  167 app_messaging_durRob_avg_friday     137 non-null    float64
#  168 app_social_dur_avg_friday           137 non-null    float64
#  169 app_social_durRob_avg_friday        137 non-null    float64
#  170 call_out_num_avg_saturday           137 non-null    float64
#  171 call_out_dur_avg_saturday           137 non-null    float64
#  172 call_in_num_avg_saturday            137 non-null    float64
#  173 call_in_dur_avg_saturday            137 non-null    float64
#  174 sms_in_num_avg_saturday             137 non-null    float64
#  175 sms_out_num_avg_saturday            137 non-null    float64
#  176 sms_in_len_avg_saturday             137 non-null    float64
#  177 sms_out_len_avg_saturday            137 non-null    float64
#  178 app_messaging_num_avg_saturday      137 non-null    float64
#  179 app_social_num_avg_saturday         137 non-null    float64
#  180 app_messaging_dur_avg_saturday      137 non-null    float64
#  181 app_messaging_durRob_avg_saturday   137 non-null    float64
#  182 app_social_dur_avg_saturday         137 non-null    float64
#  183 app_social_durRob_avg_saturday      137 non-null    float64
#  184 call_out_num_avg_sunday             137 non-null    float64
#  185 call_out_dur_avg_sunday             137 non-null    float64
#  186 call_in_num_avg_sunday              137 non-null    float64
#  187 call_in_dur_avg_sunday              137 non-null    float64
#  188 sms_in_num_avg_sunday               137 non-null    float64
#  189 sms_out_num_avg_sunday              137 non-null    float64
#  190 sms_in_len_avg_sunday               137 non-null    float64
#  191 sms_out_len_avg_sunday              137 non-null    float64
#  192 app_messaging_num_avg_sunday        137 non-null    float64
#  193 app_social_num_avg_sunday           137 non-null    float64
#  194 app_messaging_dur_avg_sunday        137 non-null    float64
#  195 app_messaging_durRob_avg_sunday     137 non-null    float64
#  196 app_social_dur_avg_sunday           137 non-null    float64
#  197 app_social_durRob_avg_sunday        137 non-null    float64
#  198 demog_age                           137 non-null    int64
#  199 demog_sex                           137 non-null    object
#  200 BFSI_O                              137 non-null    float64
#  201 BFSI_C                              137 non-null    float64
#  202 BFSI_E                              137 non-null    float64
#  203 BFSI_A                              137 non-null    float64
#  204 BFSI_N                              137 non-null    float64
# dtypes: float64(201), int64(3), object(1)
# memory usage: 219.5+ KB

# %%
df_s3_social_behaviors['demog_sex'].value_counts()
# Out:
# f    87
# m    50
# Name: demog_sex, dtype: int64

# %%
import numpy as np
pd.set_option('display.max_rows', None)

print(df_s3_social_behaviors[df_s3_social_behaviors.columns[1:]].corr()['BFSI_E'][:].sort_values(ascending=False))
# Out:
# BFSI_E                                1.000000
# BFSI_O                                0.585713
# BFSI_A                                0.380763
# app_messaging_num_avg_afternoon       0.304804
# app_messaging_num_avg_monday          0.295277
# app_messaging_num_avg_thursday        0.294517
# app_messaging_num_avg_weekdays        0.292597
# app_messaging_num_avg_friday          0.290582
# app_messaging_num_avg_morning         0.285537
# app_messaging_num_avg_wednesday       0.281252
# app_messaging_num_avg_daily           0.277395
# app_messaging_dur_avg_daily           0.263664
# app_social_dur_avg_daily              0.263664
# app_messaging_num_avg_tuesday         0.259954
# BFSI_C                                0.254594
# app_messaging_num_avg_evening         0.252604
# sms_in_len_avg_monday                 0.236145
# sms_out_num_avg_monday                0.229722
# sms_out_len_avg_monday                0.229256
# app_messaging_num_avg_weekends        0.225467
# app_messaging_num_avg_saturday        0.222550
# app_messaging_num_avg_sunday          0.222053
# sms_in_len_avg_weekends               0.216210
# sms_out_len_avg_morning               0.210017
# sms_in_len_avg_daily                  0.207946
# call_out_num_avg_thursday             0.207466
# sms_out_num_avg_afternoon             0.205788
# sms_out_num_avg_weekdays              0.205558
# app_social_durRob_avg_sunday          0.204597
# sms_out_num_avg_morning               0.203683
# call_out_num_avg_evening              0.202675
# call_out_num_avg_friday               0.200560
# call_in_num_avg_thursday              0.199097
# sms_out_num_avg_daily                 0.198700
# app_social_num_avg_sunday             0.197212
# sms_out_num_avg_wednesday             0.195713
# sms_in_len_avg_saturday               0.193722
# sms_out_len_avg_afternoon             0.193541
# call_out_num_avg_daily                0.193308
# call_out_num_avg_weekends             0.191701
# sms_in_len_avg_sunday                 0.189733
# sms_in_len_avg_weekdays               0.189692
# sms_out_num_avg_friday                0.189087
# sms_in_len_avg_afternoon              0.188907
# call_out_num_avg_weekdays             0.188447
# sms_in_len_avg_evening                0.187809
# app_social_dur_avg_weekdays           0.185874
# app_messaging_dur_avg_weekdays        0.185874
# sms_in_len_avg_morning                0.184662
# sms_in_num_avg_weekends               0.184147
# call_out_num_avg_saturday             0.184097
# call_in_num_avg_weekdays              0.182370
# call_out_num_avg_sunday               0.181729
# call_out_num_avg_afternoon            0.180488
# sms_out_len_avg_weekdays              0.179351
# sms_out_num_avg_saturday              0.176971
# sms_in_num_avg_sunday                 0.176926
# sms_out_num_avg_thursday              0.173695
# app_messaging_durRob_avg_afternoon    0.173124
# app_social_durRob_avg_weekends        0.172989
# sms_out_len_avg_friday                0.172911
# sms_out_len_avg_daily                 0.172818
# call_in_num_avg_daily                 0.172578
# sms_in_num_avg_saturday               0.172526
# app_social_num_avg_afternoon          0.171898
# sms_out_num_avg_tuesday               0.170764
# app_messaging_durRob_avg_thursday     0.169989
# sms_in_len_avg_friday                 0.169061
# app_messaging_durRob_avg_monday       0.168384
# app_social_num_avg_weekends           0.167953
# call_out_num_avg_monday               0.167917
# call_in_num_avg_tuesday               0.166689
# sms_out_num_avg_evening               0.163983
# sms_in_num_avg_morning                0.163627
# sms_in_num_avg_daily                  0.162465
# call_in_num_avg_evening               0.162448
# sms_out_num_avg_weekends              0.160218
# call_out_num_avg_wednesday            0.159665
# sms_in_num_avg_monday                 0.158491
# app_messaging_durRob_avg_weekdays     0.156140
# app_messaging_durRob_avg_morning      0.152887
# app_messaging_dur_avg_morning         0.152777
# app_social_dur_avg_morning            0.152777
# call_in_num_avg_wednesday             0.150807
# call_in_num_avg_saturday              0.150713
# sms_out_len_avg_tuesday               0.150460
# sms_in_len_avg_thursday               0.150283
# sms_in_num_avg_afternoon              0.150181
# sms_in_len_avg_wednesday              0.149862
# app_social_num_avg_friday             0.149006
# app_messaging_durRob_avg_friday       0.147921
# sms_in_num_avg_weekdays               0.147484
# app_social_durRob_avg_afternoon       0.146591
# app_social_num_avg_daily              0.146480
# sms_in_num_avg_friday                 0.146191
# sms_in_num_avg_thursday               0.144836
# call_out_num_avg_night                0.143848
# app_messaging_durRob_avg_daily        0.143140
# sms_out_len_avg_weekends              0.142414
# call_in_num_avg_friday                0.142307
# call_in_num_avg_afternoon             0.141836
# app_social_num_avg_saturday           0.141715
# sms_in_num_avg_evening                0.141061
# call_out_num_avg_morning              0.140850
# app_messaging_durRob_avg_wednesday    0.140581
# sms_out_len_avg_thursday              0.140103
# call_out_num_avg_tuesday              0.140023
# app_social_durRob_avg_saturday        0.137074
# app_social_num_avg_wednesday          0.135852
# call_in_num_avg_morning               0.135099
# app_social_num_avg_weekdays           0.135026
# sms_out_len_avg_wednesday             0.134606
# app_social_num_avg_tuesday            0.134548
# app_social_num_avg_evening            0.132336
# sms_out_len_avg_sunday                0.131404
# app_social_num_avg_thursday           0.129174
# app_messaging_durRob_avg_evening      0.129057
# app_social_durRob_avg_daily           0.128586
# sms_out_num_avg_night                 0.128577
# app_social_durRob_avg_evening         0.128137
# app_social_durRob_avg_thursday        0.127744
# call_in_num_avg_weekends              0.125901
# app_social_durRob_avg_night           0.123486
# sms_out_num_avg_sunday                0.123249
# call_out_dur_avg_night                0.118415
# sms_in_num_avg_tuesday                0.118106
# app_social_num_avg_monday             0.114847
# sms_in_len_avg_night                  0.113969
# sms_out_len_avg_saturday              0.113215
# app_social_durRob_avg_weekdays        0.112504
# app_social_num_avg_night              0.112272
# sms_in_num_avg_night                  0.112238
# app_social_durRob_avg_wednesday       0.111687
# call_in_num_avg_monday                0.111155
# app_social_durRob_avg_friday          0.110990
# app_social_num_avg_morning            0.106920
# sms_out_len_avg_evening               0.106702
# call_out_dur_avg_saturday             0.105050
# sms_in_len_avg_tuesday                0.102014
# sms_in_num_avg_wednesday              0.098003
# app_messaging_num_avg_night           0.097374
# app_messaging_durRob_avg_tuesday      0.097029
# call_out_dur_avg_tuesday              0.094491
# app_social_durRob_avg_monday          0.093579
# app_messaging_dur_avg_afternoon       0.092716
# app_social_dur_avg_afternoon          0.092716
# app_messaging_dur_avg_evening         0.092062
# app_social_dur_avg_evening            0.092062
# app_messaging_durRob_avg_sunday       0.090122
# app_social_durRob_avg_morning         0.088351
# app_social_durRob_avg_tuesday         0.086409
# call_out_dur_avg_weekends             0.085982
# call_out_dur_avg_friday               0.085253
# app_messaging_durRob_avg_saturday     0.082051
# app_messaging_durRob_avg_weekends     0.081462
# call_out_dur_avg_daily                0.081387
# call_out_dur_avg_evening              0.081007
# app_social_dur_avg_monday             0.080757
# app_messaging_dur_avg_monday          0.080757
# call_out_dur_avg_weekdays             0.074159
# call_out_dur_avg_wednesday            0.067515
# call_out_dur_avg_afternoon            0.067224
# sms_out_len_avg_night                 0.066214
# call_in_num_avg_sunday                0.063654
# app_social_dur_avg_tuesday            0.060417
# app_messaging_dur_avg_tuesday         0.060417
# call_in_dur_avg_afternoon             0.060317
# app_social_dur_avg_wednesday          0.059155
# app_messaging_dur_avg_wednesday       0.059155
# call_in_num_avg_night                 0.055210
# userid                                0.053512
# call_in_dur_avg_saturday              0.046487
# call_in_dur_avg_thursday              0.044803
# call_out_dur_avg_morning              0.044639
# call_out_dur_avg_sunday               0.041235
# call_in_dur_avg_night                 0.039260
# app_messaging_dur_avg_friday          0.037006
# app_social_dur_avg_friday             0.037006
# call_out_dur_avg_thursday             0.029897
# call_out_dur_avg_monday               0.028992
# demog_age                             0.028718
# call_in_dur_avg_monday                0.027209
# app_messaging_dur_avg_night           0.026424
# app_social_dur_avg_night              0.026424
# call_in_dur_avg_weekdays              0.026159
# call_in_dur_avg_wednesday             0.020636
# call_in_dur_avg_friday                0.013023
# call_in_dur_avg_daily                 0.012968
# call_in_dur_avg_morning               0.012759
# app_messaging_dur_avg_thursday        0.006563
# app_social_dur_avg_thursday           0.006563
# call_in_dur_avg_tuesday              -0.016388
# app_messaging_dur_avg_saturday       -0.030292
# app_social_dur_avg_saturday          -0.030292
# call_in_dur_avg_evening              -0.031234
# call_in_dur_avg_weekends             -0.032533
# app_messaging_durRob_avg_night       -0.042123
# app_social_dur_avg_weekends          -0.088630
# app_messaging_dur_avg_weekends       -0.088630
# app_messaging_dur_avg_sunday         -0.102363
# app_social_dur_avg_sunday            -0.102363
# call_in_dur_avg_sunday               -0.107215
# BFSI_N                               -0.465391
# Name: BFSI_E, dtype: float64

# %%
df_s3_social_behaviors
# Out:
#      int64_field_0  userid  call_out_num_avg_daily  ...  BFSI_E  BFSI_A  BFSI_N
# 0                8   17399                0.000000  ...  0.5066 -0.8064  0.8745
# 1                9   18336                0.000000  ... -0.0090 -0.0711  0.3583
# 2               10   18818                0.034483  ...  0.4861  0.7732 -0.7022
# 3               15   20439                0.033333  ... -0.1673 -0.1943 -0.3104
# 4               16   22271                0.000000  ... -0.4207 -0.3580  0.2921
# 5               18   23429                0.000000  ...  0.1202  0.5388 -0.0578
# 6               24   25835                0.033333  ... -0.3042  0.1372  0.8701
# 7               29   28017                0.033333  ... -0.7105 -0.0816  0.1301
# 8               31   28923                0.033333  ... -0.0139 -0.4345 -0.5131
# 9               32   30645                0.033333  ...  0.5896 -0.8064 -1.2249
# 10              33   30932                0.033333  ...  0.3116 -0.3513  0.8678
# 11              36   32944                0.033333  ... -0.4987 -0.3466  0.2227
# 12              37   33992                0.033333  ...  1.3308  0.7418 -0.9286
# 13              43   36482                0.033333  ...  1.5174  0.8568 -0.2485
# 14              44   36803                0.033333  ...  0.4459  1.4299 -1.0689
# 15              45   37106                0.033333  ... -0.4538 -0.3979  0.2838
# 16              51   38841                0.033333  ... -0.1890  0.3804  0.8097
# 17              57   42719                0.066667  ...  0.2496 -0.3595  0.1270
# 18              58   43225                0.000000  ...  1.1506  1.1220  0.0109
# 19              65   47704                0.370370  ... -1.0883 -0.5941  0.0901
# 20              68   48290                0.033333  ...  1.1019 -1.2450 -0.5762
# 21              70   50708                0.034483  ... -1.9760 -0.3104  1.9955
# 22              73   53122                0.033333  ...  0.0131  0.6947 -0.6027
# 23              76   56351                0.033333  ... -1.0514  0.2736  0.8136
# 24              78   58173                0.033333  ...  0.4585  0.8024  0.3596
# 25              87   67671                0.033333  ...  0.3873 -0.1562  0.7211
# 26              89   67851                0.033333  ... -0.1679 -0.7287  0.6418
# 27              90   69148                0.033333  ...  0.1435 -0.3104  0.2850
# 28              92   71826                0.033333  ...  0.2571 -0.7242 -0.3624
# 29              95   73284                0.033333  ... -1.7403 -0.7546  0.9866
# 30              97   73968                0.058824  ...  1.4156  0.2126 -0.4907
# 31             104   78827                0.000000  ...  0.4948  0.5605  0.4094
# 32             106   79960                0.033333  ...  0.6032  0.2469 -0.4623
# 33             112   85351                0.033333  ...  1.2150  0.2822 -0.4215
# 34             114   88988                0.000000  ... -0.3395  0.3308 -0.0159
# 35             118   91689                0.000000  ... -1.0755 -0.8934  1.5660
# 36             136   97058                0.033333  ... -0.1296 -0.6276 -0.1081
# 37               2   11491                0.266667  ... -1.1607 -2.1099 -1.1622
# 38              34   32611                0.400000  ... -0.4810 -1.9340  0.7051
# 39              39   34745                0.000000  ... -0.3575 -0.2853 -0.1710
# 40              83   65400                0.200000  ...  0.3735 -0.0576  0.4887
# 41              81   62245                0.600000  ... -0.6752 -0.2450 -0.7803
# 42              80   61577                1.600000  ... -0.3048  0.5376 -0.3670
# 43              69   49459                0.566667  ...  0.8248 -0.9876 -0.2510
# 44              96   73858                0.700000  ... -0.9128 -0.0184  1.1705
# 45              71   51117                1.266667  ...  0.1131 -1.7899 -0.4933
# 46              50   38334                0.466667  ... -0.7047  0.4948 -0.8088
# 47             110   82288                0.666667  ... -0.5109  0.5479 -0.1254
# 48              98   74356                0.233333  ...  0.1005 -1.1705 -0.2729
# 49              12   19612                0.333333  ...  0.2438  0.3805 -1.2184
# 50              53   39750                0.433333  ... -1.5658 -0.9255  0.9453
# 51              91   71825                0.066667  ... -0.7452  0.1857  0.5454
# 52             105   79050                0.714286  ... -0.5252 -0.4115 -0.8788
# 53             121   93127                3.866667  ... -0.0391 -0.2393  0.9162
# 54              88   67826                0.566667  ... -0.1509  0.1776 -0.4865
# 55              67   48097                4.500000  ...  0.5429 -0.7836 -0.0697
# 56             113   87358                0.533333  ...  1.7100  1.8009 -2.5201
# 57               3   12552                0.566667  ... -0.2877 -0.1796  1.6827
# 58              85   65493                3.866667  ...  0.1029  0.6758 -0.2100
# 59              19   23439                3.766667  ...  1.8134  0.3358  0.1554
# 60             125   94406                1.866667  ... -0.1266 -0.3002  0.9458
# 61              13   20180                1.700000  ... -0.0876 -0.5062  0.7997
# 62              35   32670                0.000000  ...  0.4199  0.1212 -0.2737
# 63              41   36099                0.033333  ... -0.3020 -0.1890  0.2251
# 64             115   89849                0.000000  ... -1.6782 -1.0734  0.4200
# 65             133   95933                0.000000  ... -0.7133 -0.1877  0.3998
# 66              77   57679                0.266667  ... -0.9546 -1.2251  0.6083
# 67              59   43639                1.083333  ...  0.4850 -0.2812 -1.1739
# 68             127   94601                0.766667  ... -0.5190 -0.5429 -0.9399
# 69              40   35018                1.633333  ...  0.3188 -0.1704  0.0757
# 70              54   39976                1.333333  ...  1.0249 -0.1781  0.0475
# 71              82   62574                1.200000  ...  0.0539  0.5197 -0.2139
# 72              66   47878                0.766667  ...  0.5911  0.3139 -0.8866
# 73              47   37480                0.600000  ... -0.1507 -0.9033  0.5264
# 74             109   81933                0.300000  ... -0.7023 -1.6789  0.3859
# 75              21   24761                0.933333  ... -0.6097 -0.8317 -0.0399
# 76              61   45244                0.533333  ... -0.4205  0.4405 -0.5817
# 77              60   44703                2.866667  ...  1.5418  1.0150 -1.3899
# 78              94   72706                1.033333  ... -0.2833  0.9425  0.6814
# 79              72   51247                0.633333  ... -0.1731  0.0463  0.0148
# 80             130   95470                2.000000  ...  1.1332  1.7466 -1.3524
# 81             135   96622                0.933333  ...  0.5488 -0.3952  0.9277
# 82             107   80202                1.433333  ...  0.6310  1.6678  0.0519
# 83             131   95538                7.600000  ...  0.0915  0.1261  0.4131
# 84              52   39133                0.966667  ... -0.6814  1.5504 -0.6756
# 85              30   28756                1.300000  ... -0.1242  0.2737  0.2914
# 86              48   37702                0.700000  ... -0.1619  0.1046  0.1349
# 87              46   37209                2.766667  ... -0.0720 -0.1468  0.2250
# 88             134   96502                1.466667  ... -0.3749 -0.5912  0.0749
# 89               7   15693                0.300000  ... -0.9906 -1.2005  1.4149
# 90             122   93654                0.866667  ... -0.3941  0.5678  1.0914
# 91              49   37705                0.566667  ...  0.7861 -0.0249  1.2234
# 92             111   83779                2.233333  ...  0.6448 -0.4934 -0.8899
# 93             119   91709                0.666667  ...  0.0233 -0.2352 -0.0700
# 94             117   91278                1.965517  ... -0.4658 -0.4062 -0.3004
# 95             120   92814                1.900000  ...  1.1473 -0.1024 -0.4913
# 96               6   14154                0.833333  ... -0.1213 -0.9829 -0.5203
# 97              79   58444                0.666667  ... -0.8661 -0.9867  0.1844
# 98              62   45452                1.000000  ... -1.1970  0.0271 -0.1680
# 99             100   77267                3.300000  ...  0.1859 -0.4958 -0.4044
# 100            116   90885                1.966667  ...  0.5906  1.0854 -0.7845
# 101             42   36144                8.100000  ... -0.3316 -0.4142  0.2662
# 102             86   67174                2.600000  ...  1.3940 -0.7315  0.2274
# 103            102   77873                2.333333  ... -0.7625 -0.5559  0.3929
# 104             56   41883                2.933333  ... -0.2597 -0.4688  1.5321
# 105             63   46655                1.066667  ...  0.4679  0.1948  0.2262
# 106             38   34196                3.166667  ... -0.1040 -0.9828  0.1549
# 107            101   77598                2.900000  ...  0.1149  1.7442  0.6915
# 108             93   71978                1.333333  ...  1.8764  0.6638 -0.5338
# 109            126   94479                6.066667  ... -0.0007 -0.1276 -0.4939
# 110            123   94005                5.800000  ...  0.2838  0.4979 -0.4445
# 111             84   65403                2.300000  ...  1.1272 -0.4152 -0.6847
# 112              1   11304                0.666667  ... -1.0278 -1.4482  0.9334
# 113            132   95904                0.733333  ...  0.3693 -0.3926 -0.5888
# 114             74   53503                4.333333  ... -0.4628 -1.4083  1.2092
# 115             28   27993                2.166667  ...  0.0733 -0.8045  0.0768
# 116            128   95152                0.000000  ...  0.2502  1.0393 -0.2777
# 117             17   22718                0.600000  ...  0.7477 -0.9170 -0.4077
# 118              5   13604                1.000000  ...  0.3674 -0.6329 -0.1927
# 119            108   81076                2.200000  ... -0.1341 -0.2242  0.1440
# 120             11   19533                2.400000  ...  0.7423  0.8434  0.5761
# 121             26   26192                0.300000  ... -0.6576 -0.3414 -0.0026
# 122             99   76030                0.333333  ... -0.6146 -1.4579  0.5337
# 123              4   13275                0.300000  ... -0.8416 -0.8495  0.8580
# 124             25   25870                1.833333  ...  0.0607 -0.3474  0.1372
# 125             27   26690                1.400000  ...  0.3846  0.3893 -0.2290
# 126            129   95295                0.133333  ... -0.4986  0.0317  1.0175
# 127             23   25495                1.033333  ...  0.6199 -1.0705 -0.7339
# 128             55   40864                2.333333  ...  0.8545 -0.1442 -0.4303
# 129             22   25282                0.633333  ...  0.5965 -0.0414 -0.1202
# 130            103   78794                2.933333  ...  0.0456  0.0234 -0.0324
# 131             14   20317                1.466667  ... -0.2683 -0.0071 -0.2102
# 132             20   23497                1.933333  ... -0.6034 -0.8169  0.4073
# 133             64   47702                1.566667  ...  0.0828 -0.1387  0.1752
# 134            137   99007                5.133333  ...  0.8106  0.1873 -0.0239
# 135            124   94115                5.500000  ...  1.1152 -0.7516  0.0240
# 136             75   54633                4.366667  ...  0.1472 -0.6465  0.0755
#
# [137 rows x 205 columns]

# %%
import pandas as pd
import numpy as np

dum_df = pd.get_dummies(df_s3_social_behaviors, columns=["demog_sex"] )
dum_df
# Out:
#      int64_field_0  userid  ...  demog_sex_f  demog_sex_m
# 0                8   17399  ...            1            0
# 1                9   18336  ...            1            0
# 2               10   18818  ...            1            0
# 3               15   20439  ...            1            0
# 4               16   22271  ...            1            0
# 5               18   23429  ...            1            0
# 6               24   25835  ...            1            0
# 7               29   28017  ...            1            0
# 8               31   28923  ...            1            0
# 9               32   30645  ...            1            0
# 10              33   30932  ...            0            1
# 11              36   32944  ...            1            0
# 12              37   33992  ...            1            0
# 13              43   36482  ...            1            0
# 14              44   36803  ...            1            0
# 15              45   37106  ...            1            0
# 16              51   38841  ...            0            1
# 17              57   42719  ...            1            0
# 18              58   43225  ...            1            0
# 19              65   47704  ...            1            0
# 20              68   48290  ...            0            1
# 21              70   50708  ...            1            0
# 22              73   53122  ...            1            0
# 23              76   56351  ...            1            0
# 24              78   58173  ...            1            0
# 25              87   67671  ...            1            0
# 26              89   67851  ...            1            0
# 27              90   69148  ...            1            0
# 28              92   71826  ...            1            0
# 29              95   73284  ...            1            0
# 30              97   73968  ...            1            0
# 31             104   78827  ...            1            0
# 32             106   79960  ...            1            0
# 33             112   85351  ...            1            0
# 34             114   88988  ...            1            0
# 35             118   91689  ...            0            1
# 36             136   97058  ...            1            0
# 37               2   11491  ...            0            1
# 38              34   32611  ...            0            1
# 39              39   34745  ...            0            1
# 40              83   65400  ...            0            1
# 41              81   62245  ...            0            1
# 42              80   61577  ...            1            0
# 43              69   49459  ...            1            0
# 44              96   73858  ...            1            0
# 45              71   51117  ...            0            1
# 46              50   38334  ...            1            0
# 47             110   82288  ...            0            1
# 48              98   74356  ...            0            1
# 49              12   19612  ...            0            1
# 50              53   39750  ...            0            1
# 51              91   71825  ...            0            1
# 52             105   79050  ...            0            1
# 53             121   93127  ...            1            0
# 54              88   67826  ...            0            1
# 55              67   48097  ...            0            1
# 56             113   87358  ...            0            1
# 57               3   12552  ...            1            0
# 58              85   65493  ...            1            0
# 59              19   23439  ...            0            1
# 60             125   94406  ...            1            0
# 61              13   20180  ...            1            0
# 62              35   32670  ...            1            0
# 63              41   36099  ...            1            0
# 64             115   89849  ...            0            1
# 65             133   95933  ...            1            0
# 66              77   57679  ...            0            1
# 67              59   43639  ...            0            1
# 68             127   94601  ...            1            0
# 69              40   35018  ...            1            0
# 70              54   39976  ...            1            0
# 71              82   62574  ...            1            0
# 72              66   47878  ...            1            0
# 73              47   37480  ...            1            0
# 74             109   81933  ...            0            1
# 75              21   24761  ...            0            1
# 76              61   45244  ...            0            1
# 77              60   44703  ...            1            0
# 78              94   72706  ...            1            0
# 79              72   51247  ...            0            1
# 80             130   95470  ...            1            0
# 81             135   96622  ...            1            0
# 82             107   80202  ...            0            1
# 83             131   95538  ...            1            0
# 84              52   39133  ...            0            1
# 85              30   28756  ...            1            0
# 86              48   37702  ...            0            1
# 87              46   37209  ...            1            0
# 88             134   96502  ...            0            1
# 89               7   15693  ...            0            1
# 90             122   93654  ...            1            0
# 91              49   37705  ...            1            0
# 92             111   83779  ...            0            1
# 93             119   91709  ...            1            0
# 94             117   91278  ...            0            1
# 95             120   92814  ...            1            0
# 96               6   14154  ...            0            1
# 97              79   58444  ...            1            0
# 98              62   45452  ...            0            1
# 99             100   77267  ...            0            1
# 100            116   90885  ...            0            1
# 101             42   36144  ...            0            1
# 102             86   67174  ...            1            0
# 103            102   77873  ...            1            0
# 104             56   41883  ...            0            1
# 105             63   46655  ...            1            0
# 106             38   34196  ...            0            1
# 107            101   77598  ...            1            0
# 108             93   71978  ...            1            0
# 109            126   94479  ...            1            0
# 110            123   94005  ...            1            0
# 111             84   65403  ...            1            0
# 112              1   11304  ...            0            1
# 113            132   95904  ...            1            0
# 114             74   53503  ...            0            1
# 115             28   27993  ...            0            1
# 116            128   95152  ...            1            0
# 117             17   22718  ...            1            0
# 118              5   13604  ...            1            0
# 119            108   81076  ...            0            1
# 120             11   19533  ...            1            0
# 121             26   26192  ...            1            0
# 122             99   76030  ...            1            0
# 123              4   13275  ...            1            0
# 124             25   25870  ...            1            0
# 125             27   26690  ...            1            0
# 126            129   95295  ...            1            0
# 127             23   25495  ...            1            0
# 128             55   40864  ...            0            1
# 129             22   25282  ...            1            0
# 130            103   78794  ...            0            1
# 131             14   20317  ...            1            0
# 132             20   23497  ...            0            1
# 133             64   47702  ...            1            0
# 134            137   99007  ...            0            1
# 135            124   94115  ...            0            1
# 136             75   54633  ...            1            0
#
# [137 rows x 206 columns]

# %%
dum_df.info(verbose=True,null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 206 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   int64_field_0                       137 non-null    int64
#  1   userid                              137 non-null    int64
#  2   call_out_num_avg_daily              137 non-null    float64
#  3   call_out_dur_avg_daily              137 non-null    float64
#  4   call_out_num_avg_afternoon          137 non-null    float64
#  5   call_out_dur_avg_afternoon          137 non-null    float64
#  6   call_out_num_avg_evening            137 non-null    float64
#  7   call_out_dur_avg_evening            137 non-null    float64
#  8   call_out_num_avg_morning            137 non-null    float64
#  9   call_out_dur_avg_morning            137 non-null    float64
#  10  call_out_num_avg_night              137 non-null    float64
#  11  call_out_dur_avg_night              137 non-null    float64
#  12  call_in_num_avg_daily               137 non-null    float64
#  13  call_in_dur_avg_daily               137 non-null    float64
#  14  call_in_num_avg_afternoon           137 non-null    float64
#  15  call_in_dur_avg_afternoon           137 non-null    float64
#  16  call_in_num_avg_evening             137 non-null    float64
#  17  call_in_dur_avg_evening             137 non-null    float64
#  18  call_in_num_avg_morning             137 non-null    float64
#  19  call_in_dur_avg_morning             137 non-null    float64
#  20  call_in_num_avg_night               137 non-null    float64
#  21  call_in_dur_avg_night               137 non-null    float64
#  22  sms_in_num_avg_daily                137 non-null    float64
#  23  sms_out_num_avg_daily               137 non-null    float64
#  24  sms_in_len_avg_daily                137 non-null    float64
#  25  sms_out_len_avg_daily               137 non-null    float64
#  26  app_messaging_num_avg_daily         137 non-null    float64
#  27  app_social_num_avg_daily            137 non-null    float64
#  28  app_messaging_dur_avg_daily         137 non-null    float64
#  29  app_messaging_durRob_avg_daily      137 non-null    float64
#  30  app_social_dur_avg_daily            137 non-null    float64
#  31  app_social_durRob_avg_daily         137 non-null    float64
#  32  sms_in_num_avg_afternoon            137 non-null    float64
#  33  sms_out_num_avg_afternoon           137 non-null    float64
#  34  sms_in_len_avg_afternoon            137 non-null    float64
#  35  sms_out_len_avg_afternoon           137 non-null    float64
#  36  app_messaging_num_avg_afternoon     137 non-null    float64
#  37  app_social_num_avg_afternoon        137 non-null    float64
#  38  app_messaging_dur_avg_afternoon     137 non-null    float64
#  39  app_messaging_durRob_avg_afternoon  137 non-null    float64
#  40  app_social_dur_avg_afternoon        137 non-null    float64
#  41  app_social_durRob_avg_afternoon     137 non-null    float64
#  42  sms_in_num_avg_evening              137 non-null    float64
#  43  sms_out_num_avg_evening             137 non-null    float64
#  44  sms_in_len_avg_evening              137 non-null    float64
#  45  sms_out_len_avg_evening             137 non-null    float64
#  46  app_messaging_num_avg_evening       137 non-null    float64
#  47  app_social_num_avg_evening          137 non-null    float64
#  48  app_messaging_dur_avg_evening       137 non-null    float64
#  49  app_messaging_durRob_avg_evening    137 non-null    float64
#  50  app_social_dur_avg_evening          137 non-null    float64
#  51  app_social_durRob_avg_evening       137 non-null    float64
#  52  sms_in_num_avg_morning              137 non-null    float64
#  53  sms_out_num_avg_morning             137 non-null    float64
#  54  sms_in_len_avg_morning              137 non-null    float64
#  55  sms_out_len_avg_morning             137 non-null    float64
#  56  app_messaging_num_avg_morning       137 non-null    float64
#  57  app_social_num_avg_morning          137 non-null    float64
#  58  app_messaging_dur_avg_morning       137 non-null    float64
#  59  app_messaging_durRob_avg_morning    137 non-null    float64
#  60  app_social_dur_avg_morning          137 non-null    float64
#  61  app_social_durRob_avg_morning       137 non-null    float64
#  62  sms_in_num_avg_night                137 non-null    float64
#  63  sms_out_num_avg_night               137 non-null    float64
#  64  sms_in_len_avg_night                137 non-null    float64
#  65  sms_out_len_avg_night               137 non-null    float64
#  66  app_messaging_num_avg_night         137 non-null    float64
#  67  app_social_num_avg_night            137 non-null    float64
#  68  app_messaging_dur_avg_night         137 non-null    float64
#  69  app_messaging_durRob_avg_night      137 non-null    float64
#  70  app_social_dur_avg_night            137 non-null    float64
#  71  app_social_durRob_avg_night         137 non-null    float64
#  72  call_out_num_avg_weekends           137 non-null    float64
#  73  call_out_dur_avg_weekends           137 non-null    float64
#  74  call_in_num_avg_weekends            137 non-null    float64
#  75  call_in_dur_avg_weekends            137 non-null    float64
#  76  sms_in_num_avg_weekends             137 non-null    float64
#  77  sms_out_num_avg_weekends            137 non-null    float64
#  78  sms_in_len_avg_weekends             137 non-null    float64
#  79  sms_out_len_avg_weekends            137 non-null    float64
#  80  app_messaging_num_avg_weekends      137 non-null    float64
#  81  app_social_num_avg_weekends         137 non-null    float64
#  82  app_messaging_dur_avg_weekends      137 non-null    float64
#  83  app_messaging_durRob_avg_weekends   137 non-null    float64
#  84  app_social_dur_avg_weekends         137 non-null    float64
#  85  app_social_durRob_avg_weekends      137 non-null    float64
#  86  call_out_num_avg_weekdays           137 non-null    float64
#  87  call_out_dur_avg_weekdays           137 non-null    float64
#  88  call_in_num_avg_weekdays            137 non-null    float64
#  89  call_in_dur_avg_weekdays            137 non-null    float64
#  90  sms_in_num_avg_weekdays             137 non-null    float64
#  91  sms_out_num_avg_weekdays            137 non-null    float64
#  92  sms_in_len_avg_weekdays             137 non-null    float64
#  93  sms_out_len_avg_weekdays            137 non-null    float64
#  94  app_messaging_num_avg_weekdays      137 non-null    float64
#  95  app_social_num_avg_weekdays         137 non-null    float64
#  96  app_messaging_dur_avg_weekdays      137 non-null    float64
#  97  app_messaging_durRob_avg_weekdays   137 non-null    float64
#  98  app_social_dur_avg_weekdays         137 non-null    float64
#  99  app_social_durRob_avg_weekdays      137 non-null    float64
#  100 call_out_num_avg_monday             137 non-null    float64
#  101 call_out_dur_avg_monday             137 non-null    float64
#  102 call_in_num_avg_monday              137 non-null    float64
#  103 call_in_dur_avg_monday              137 non-null    float64
#  104 sms_in_num_avg_monday               137 non-null    float64
#  105 sms_out_num_avg_monday              137 non-null    float64
#  106 sms_in_len_avg_monday               137 non-null    float64
#  107 sms_out_len_avg_monday              137 non-null    float64
#  108 app_messaging_num_avg_monday        137 non-null    float64
#  109 app_social_num_avg_monday           137 non-null    float64
#  110 app_messaging_dur_avg_monday        137 non-null    float64
#  111 app_messaging_durRob_avg_monday     137 non-null    float64
#  112 app_social_dur_avg_monday           137 non-null    float64
#  113 app_social_durRob_avg_monday        137 non-null    float64
#  114 call_out_num_avg_tuesday            137 non-null    float64
#  115 call_out_dur_avg_tuesday            137 non-null    float64
#  116 call_in_num_avg_tuesday             137 non-null    float64
#  117 call_in_dur_avg_tuesday             137 non-null    float64
#  118 sms_in_num_avg_tuesday              137 non-null    float64
#  119 sms_out_num_avg_tuesday             137 non-null    float64
#  120 sms_in_len_avg_tuesday              137 non-null    float64
#  121 sms_out_len_avg_tuesday             137 non-null    float64
#  122 app_messaging_num_avg_tuesday       137 non-null    float64
#  123 app_social_num_avg_tuesday          137 non-null    float64
#  124 app_messaging_dur_avg_tuesday       137 non-null    float64
#  125 app_messaging_durRob_avg_tuesday    137 non-null    float64
#  126 app_social_dur_avg_tuesday          137 non-null    float64
#  127 app_social_durRob_avg_tuesday       137 non-null    float64
#  128 call_out_num_avg_wednesday          137 non-null    float64
#  129 call_out_dur_avg_wednesday          137 non-null    float64
#  130 call_in_num_avg_wednesday           137 non-null    float64
#  131 call_in_dur_avg_wednesday           137 non-null    float64
#  132 sms_in_num_avg_wednesday            137 non-null    float64
#  133 sms_out_num_avg_wednesday           137 non-null    float64
#  134 sms_in_len_avg_wednesday            137 non-null    float64
#  135 sms_out_len_avg_wednesday           137 non-null    float64
#  136 app_messaging_num_avg_wednesday     137 non-null    float64
#  137 app_social_num_avg_wednesday        137 non-null    float64
#  138 app_messaging_dur_avg_wednesday     137 non-null    float64
#  139 app_messaging_durRob_avg_wednesday  137 non-null    float64
#  140 app_social_dur_avg_wednesday        137 non-null    float64
#  141 app_social_durRob_avg_wednesday     137 non-null    float64
#  142 call_out_num_avg_thursday           137 non-null    float64
#  143 call_out_dur_avg_thursday           137 non-null    float64
#  144 call_in_num_avg_thursday            137 non-null    float64
#  145 call_in_dur_avg_thursday            137 non-null    float64
#  146 sms_in_num_avg_thursday             137 non-null    float64
#  147 sms_out_num_avg_thursday            137 non-null    float64
#  148 sms_in_len_avg_thursday             137 non-null    float64
#  149 sms_out_len_avg_thursday            137 non-null    float64
#  150 app_messaging_num_avg_thursday      137 non-null    float64
#  151 app_social_num_avg_thursday         137 non-null    float64
#  152 app_messaging_dur_avg_thursday      137 non-null    float64
#  153 app_messaging_durRob_avg_thursday   137 non-null    float64
#  154 app_social_dur_avg_thursday         137 non-null    float64
#  155 app_social_durRob_avg_thursday      137 non-null    float64
#  156 call_out_num_avg_friday             137 non-null    float64
#  157 call_out_dur_avg_friday             137 non-null    float64
#  158 call_in_num_avg_friday              137 non-null    float64
#  159 call_in_dur_avg_friday              137 non-null    float64
#  160 sms_in_num_avg_friday               137 non-null    float64
#  161 sms_out_num_avg_friday              137 non-null    float64
#  162 sms_in_len_avg_friday               137 non-null    float64
#  163 sms_out_len_avg_friday              137 non-null    float64
#  164 app_messaging_num_avg_friday        137 non-null    float64
#  165 app_social_num_avg_friday           137 non-null    float64
#  166 app_messaging_dur_avg_friday        137 non-null    float64
#  167 app_messaging_durRob_avg_friday     137 non-null    float64
#  168 app_social_dur_avg_friday           137 non-null    float64
#  169 app_social_durRob_avg_friday        137 non-null    float64
#  170 call_out_num_avg_saturday           137 non-null    float64
#  171 call_out_dur_avg_saturday           137 non-null    float64
#  172 call_in_num_avg_saturday            137 non-null    float64
#  173 call_in_dur_avg_saturday            137 non-null    float64
#  174 sms_in_num_avg_saturday             137 non-null    float64
#  175 sms_out_num_avg_saturday            137 non-null    float64
#  176 sms_in_len_avg_saturday             137 non-null    float64
#  177 sms_out_len_avg_saturday            137 non-null    float64
#  178 app_messaging_num_avg_saturday      137 non-null    float64
#  179 app_social_num_avg_saturday         137 non-null    float64
#  180 app_messaging_dur_avg_saturday      137 non-null    float64
#  181 app_messaging_durRob_avg_saturday   137 non-null    float64
#  182 app_social_dur_avg_saturday         137 non-null    float64
#  183 app_social_durRob_avg_saturday      137 non-null    float64
#  184 call_out_num_avg_sunday             137 non-null    float64
#  185 call_out_dur_avg_sunday             137 non-null    float64
#  186 call_in_num_avg_sunday              137 non-null    float64
#  187 call_in_dur_avg_sunday              137 non-null    float64
#  188 sms_in_num_avg_sunday               137 non-null    float64
#  189 sms_out_num_avg_sunday              137 non-null    float64
#  190 sms_in_len_avg_sunday               137 non-null    float64
#  191 sms_out_len_avg_sunday              137 non-null    float64
#  192 app_messaging_num_avg_sunday        137 non-null    float64
#  193 app_social_num_avg_sunday           137 non-null    float64
#  194 app_messaging_dur_avg_sunday        137 non-null    float64
#  195 app_messaging_durRob_avg_sunday     137 non-null    float64
#  196 app_social_dur_avg_sunday           137 non-null    float64
#  197 app_social_durRob_avg_sunday        137 non-null    float64
#  198 demog_age                           137 non-null    int64
#  199 BFSI_O                              137 non-null    float64
#  200 BFSI_C                              137 non-null    float64
#  201 BFSI_E                              137 non-null    float64
#  202 BFSI_A                              137 non-null    float64
#  203 BFSI_N                              137 non-null    float64
#  204 demog_sex_f                         137 non-null    uint8
#  205 demog_sex_m                         137 non-null    uint8
# dtypes: float64(201), int64(3), uint8(2)
# memory usage: 218.7 KB

# %%
X=dum_df.drop(['BFSI_O', 'BFSI_C', 'BFSI_E','BFSI_A','BFSI_N','int64_field_0'], axis=1)

# %%
X.head()
# Out:
#    userid  call_out_num_avg_daily  ...  demog_sex_f  demog_sex_m
# 0   17399                0.000000  ...            1            0
# 1   18336                0.000000  ...            1            0
# 2   18818                0.034483  ...            1            0
# 3   20439                0.033333  ...            1            0
# 4   22271                0.000000  ...            1            0
#
# [5 rows x 200 columns]

# %%
y = dum_df[['BFSI_O', 'BFSI_C', 'BFSI_E','BFSI_A','BFSI_N']].copy()

# %%
y.head()
# Out:
#    BFSI_O  BFSI_C  BFSI_E  BFSI_A  BFSI_N
# 0 -0.0279  0.7585  0.5066 -0.8064  0.8745
# 1 -0.1844 -0.0150 -0.0090 -0.0711  0.3583
# 2  0.0551 -1.4056  0.4861  0.7732 -0.7022
# 3 -0.0949 -1.0496 -0.1673 -0.1943 -0.3104
# 4  0.2752 -0.2635 -0.4207 -0.3580  0.2921

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X=X.values
y=y.values
xtrain, xtest, ytrain, ytest=train_test_split(X, y, test_size=0.15)
print("xtrain:", xtrain.shape, "ytrian:", ytrain.shape)

print("xtest:", xtest.shape, "ytest:", ytest.shape)

scalar=StandardScaler()
scalar.fit(xtrain)
xtrain=scalar.transform(xtrain)
xtest=scalar.transform(xtest)
# Out:
# xtrain: (116, 200) ytrian: (116, 5)
# xtest: (21, 200) ytest: (21, 5)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
#gradient bossting model
gbr = GradientBoostingRegressor(learning_rate=0.1,n_estimators=100, max_depth=1)
model = MultiOutputRegressor(estimator=gbr)
print(model)
# Out:
# MultiOutputRegressor(estimator=GradientBoostingRegressor(alpha=0.9,
#                                                          ccp_alpha=0.0,
#                                                          criterion='friedman_mse',
#                                                          init=None,
#                                                          learning_rate=0.1,
#                                                          loss='ls', max_depth=1,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          n_estimators=100,
#                                                          n_iter_no_change=None,
#                                                          presort='deprecated',
#                                                          random_state=None,
#                                                          subsample=1.0,
#                                                          tol=0.0001,
#                                                          validation_fraction=0.1,
#                                                          verbose=0,
#                                                          warm_start=False),
#                      n_jobs=None)

# %%
model.fit(xtrain, ytrain)
score = model.score(xtrain, ytrain)
print("Training score:", score)
model.score(xtest, ytest)
# Out:
# Training score: 0.5802804535303185
# -0.23499274151644522

# %%
from sklearn.metrics import mean_squared_error
ypred = model.predict(xtest)

# %%
print("y1 BFSI_O MSE:%.4f" % mean_squared_error(ytest[:,0], ypred[:,0]))
print("y2 BFSI_C MSE:%.4f" % mean_squared_error(ytest[:,1], ypred[:,1]))
print("y3 BFSI_E MSE:%.4f" % mean_squared_error(ytest[:,2], ypred[:,2]))
print("y4 BFSI_A MSE:%.4f" % mean_squared_error(ytest[:,3], ypred[:,3]))
print("y5 BFSI_N MSE:%.4f" % mean_squared_error(ytest[:,4], ypred[:,4]))
# Out:
# y1 BFSI_O MSE:0.8999
# y2 BFSI_C MSE:0.7717
# y3 BFSI_E MSE:0.7227
# y4 BFSI_A MSE:1.0285
# y5 BFSI_N MSE:0.8931

# %%
pip install autofeat
# Out:
# Requirement already satisfied: autofeat in /usr/local/lib/python3.6/dist-packages (2.0.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from autofeat) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.6/dist-packages (from autofeat) (1.1.5)
# Requirement already satisfied: sympy>=1.7.1 in /usr/local/lib/python3.6/dist-packages (from autofeat) (1.7.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from autofeat) (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from autofeat) (1.19.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from autofeat) (0.16.0)
# Requirement already satisfied: pint in /usr/local/lib/python3.6/dist-packages (from autofeat) (0.16.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->autofeat) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->autofeat) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.0->autofeat) (2018.9)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy>=1.7.1->autofeat) (1.1.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from pint->autofeat) (3.3.0)
# Requirement already satisfied: importlib-resources; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from pint->autofeat) (4.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from pint->autofeat) (20.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->autofeat) (1.15.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->pint->autofeat) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->pint->autofeat) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->pint->autofeat) (2.4.7)

# %%
def test_autofeat(dataset, feateng_steps=2):
    # load data
    X, y=dataset
    units=None
    # split in training and test parts
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)
    # run autofeat
    afreg = AutoFeatRegressor(verbose=1, feateng_steps=feateng_steps, units=units)
    # fit autofeat on less data, otherwise ridge reg model with xval will overfit on new features
    X_train_tr = afreg.fit_transform(X_train, y_train)
    X_test_tr = afreg.transform(X_test)
    print("autofeat new features:", len(afreg.new_feat_cols_))
    print("autofeat MSE on training data:", mean_squared_error(y_train, afreg.predict(X_train_tr)))
    print("autofeat MSE on test data:", mean_squared_error(y_test, afreg.predict(X_test_tr)))
    print("autofeat R^2 on training data:", r2_score(y_train, afreg.predict(X_train_tr)))
    print("autofeat R^2 on test data:", r2_score(y_test, afreg.predict(X_test_tr)))
    # train rreg on transformed train split incl cross-validation for parameter selection
    print("# Ridge Regression")
    rreg = Ridge()
    param_grid = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        gsmodel = GridSearchCV(rreg, param_grid, scoring='neg_mean_squared_error', cv=5)
        gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))
    print("# Random Forest")
    rforest = RandomForestRegressor(n_estimators=100, random_state=13)
    param_grid = {"min_samples_leaf": [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2]}
    gsmodel = GridSearchCV(rforest, param_grid, scoring='neg_mean_squared_error', cv=5)
    gsmodel.fit(X_train_tr, y_train)
    print("best params:", gsmodel.best_params_)
    print("best score:", gsmodel.best_score_)
    print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train_tr)))
    print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test_tr)))
    print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train_tr)))
    print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test_tr)))

# %%
import os
import sys
import warnings
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston, load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

from autofeat import AutoFeatRegressor

# %%
test_autofeat((xtrain, ytrain[:,0]), feateng_steps=1)
# Out:
# [AutoFeat] The 1 step feature engineering process could generate up to 1400 features.
# [AutoFeat] With 92 data points this new feature matrix would use about 0.00 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 989 transformed features from 200 original features - done.
# [feateng] Generated altogether 989 new features in 1 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 916 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 9 features after 5 feature selection runs
# [featsel] 7 features after correlation filtering
# [featsel] 0 features after noise filtering
# [featsel] WARNING: Not a single good features was found...
# [AutoFeat] Final dataframe with 200 feature columns (0 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# -0.038163043478260834
# [AutoFeat] Final score: 0.0000
# autofeat new features: 0
# autofeat MSE on training data: 0.5393146808081285
# autofeat MSE on test data: 0.24544238705419028
# autofeat R^2 on training data: 0.0
# autofeat R^2 on test data: -0.048260361147811626
# # Ridge Regression
# best params: {'alpha': 1000.0}
# best score: -0.5302745154402753
# MSE on training data: 0.43784426374139035
# MSE on test data: 0.3047357508756396
# R^2 on training data: 0.1881469588676712
# R^2 on test data: -0.30149650230145064
# # Random Forest
# best params: {'min_samples_leaf': 0.1}
# best score: -0.5190519535187266
# MSE on training data: 0.28672927356805766
# MSE on test data: 0.2806618865232595
# R^2 on training data: 0.46834513546263534
# R^2 on test data: -0.19867938891232106

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=10000)
clf.fit(xtrain, ytrain[:,2])
ypred=clf.predict(xtest)
clf.score(xtest, ytest[:,2])
# Out:
# -0.010779908776114677

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor


#adaboost model
ada = AdaBoostRegressor()
model1 = MultiOutputRegressor(estimator=ada)

# %%
model1.fit(xtrain, ytrain)
score = model1.score(xtrain, ytrain)
print("Training score:", score)
# Out:
# Training score: 0.7889266451351589

# %%
ypred = model1.predict(xtest)
print("y1 BFSI_O MSE:%.4f" % mean_squared_error(ytest[:,0], ypred[:,0]))
print("y2 BFSI_C MSE:%.4f" % mean_squared_error(ytest[:,1], ypred[:,1]))
print("y3 BFSI_E MSE:%.4f" % mean_squared_error(ytest[:,2], ypred[:,2]))
print("y4 BFSI_A MSE:%.4f" % mean_squared_error(ytest[:,3], ypred[:,3]))
print("y5 BFSI_N MSE:%.4f" % mean_squared_error(ytest[:,4], ypred[:,4]))
# Out:
# y1 BFSI_O MSE:0.9125
# y2 BFSI_C MSE:0.7957
# y3 BFSI_E MSE:0.6205
# y4 BFSI_A MSE:0.9677
# y5 BFSI_N MSE:0.7917

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
#randomforest regressor
rfr = RandomForestRegressor(n_estimators=200,max_depth=5 , max_features='log2' )
model2 = MultiOutputRegressor(estimator=rfr)
model2.fit(xtrain, ytrain)
score = model2.score(xtrain, ytrain)
print("Training score:", score,'test score', model2.score(xtest, ytest))

#decision treee
dt=DecisionTreeRegressor(max_depth=1)
model3= MultiOutputRegressor(estimator=dt)
model3.fit(xtrain, ytrain)
score = model3.score(xtrain, ytrain)
print("Training score:", score,'test score', model3.score(xtest, ytest))
#support vector regressor
svr=SVR()
model4= MultiOutputRegressor(estimator=svr)
model4.fit(xtrain, ytrain)
score = model4.score(xtrain, ytrain)
print("Training score:", score,'test score', model4.score(xtest, ytest))
# Out:
# Training score: 0.6710734020096505 test score -0.17773129189032816
# Training score: 0.12359721032464568 test score -0.24798452223398676
# Training score: 0.5982860240032626 test score -0.2025799335196486

# %%
#randomforestmodel prediction
ypred = model2.predict(xtest)
model_list=['BFSI_O ','BFSI_C','BFSI_E ','BFSI_A','BFSI_N']
print("y1 BFSI_O MSE:%.4f" % mean_squared_error(ytest[:,0], ypred[:,0]))
print("y2 BFSI_C MSE:%.4f" % mean_squared_error(ytest[:,1], ypred[:,1]))
print("y3 BFSI_E MSE:%.4f" % mean_squared_error(ytest[:,2], ypred[:,2]))
print("y4 BFSI_A MSE:%.4f" % mean_squared_error(ytest[:,3], ypred[:,3]))
print("y5 BFSI_N MSE:%.4f" % mean_squared_error(ytest[:,4], ypred[:,4]))
# Out:
# y1 BFSI_O MSE:0.8852
# y2 BFSI_C MSE:0.7012
# y3 BFSI_E MSE:0.7692
# y4 BFSI_A MSE:0.9815
# y5 BFSI_N MSE:0.7731

# %%
from sklearn.metrics import mean_squared_error, r2_score
for i,model in enumerate(model_list):
  print(model,"R2 score : %.2f" % r2_score(ytest[:,i],ypred[:,i]))
# Out:
# BFSI_O  R2 score : -0.31
# BFSI_C R2 score : -0.02
# BFSI_E  R2 score : -0.12
# BFSI_A R2 score : -0.39
# BFSI_N R2 score : -0.05

# %%
x_ax = range(len(xtest))
#plt.plot(x_ax, ytest[:,0], label="y1-test", color='c')
#plt.plot(x_ax, ypred[:,0], label="y1-pred", color='b')
plt.plot(x_ax, ytest[:,2], label="y2-test", color='m')
plt.plot(x_ax, ypred[:,2], label="y2-pred", color='r')
plt.legend()
plt.show()

# %%
#Classification Task

# %%
ytrain1=np.where(ytrain>0,1,0)
ytest1=np.where(ytest>0,1,0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
for i, val in enumerate(model_list):
  model5 = LogisticRegression( C=0.01)
  model5.fit(xtrain, ytrain1[:,i])
  y_pred=model5.predict_proba(xtest)
  #cm = confusion_matrix(ytest1[:,2], y_pred)
  pred=np.where(y_pred[:,1]>0.5,1,0)
  #print(classification_report(ytest1[:,i],pred))
  fpr, tpr, thresholds = metrics.roc_curve(ytest1[:,i],z)
  print(val,'auc:',metrics.auc(fpr, tpr))
# Out:
# BFSI_O  auc: 0.40384615384615385
# BFSI_C auc: 0.38636363636363635
# BFSI_E  auc: 0.48181818181818187
# BFSI_A auc: 0.5048076923076923
# BFSI_N auc: 0.5555555555555556
